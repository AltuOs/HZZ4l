// %% [markdown]
// ### Adaptación de plotme.sh

// %%
// Nombre de análisis.
TString analysisName = "HZZAnalysis";
// Ubicación de las salidad del análisis.
TString outputpath = "../Analysis/HZZAnalysis/Output_HZZAnalysis";

Plotting *m=new Plotting();
m->SetLumi(10064);
m->SetOption("$analysisName");
m->SetInputLocation("$analysisPath")
m->run()

// %%
// ////////////////////////////////////////////////// ///////////
// //// Código de trazado
// //// Autor: Colaboración ATLAS (2019)
// ////
// ////
// //// DESCARGO DE RESPONSABILIDAD:
// //// ¡Este software está destinado únicamente para uso educativo!
// //// ¡Bajo ninguna circunstancia califica para reproducir resultados de análisis ATLAS reales o producir resultados publicables!
// ////////////////////////////////////////////////// /////////////

// incluir encabezados ROOT y C ++
# incluir  < cadena >
# incluye  < iostream >
# incluir  < fstream >
# incluir  < sstream >
# incluir  < vector >
# incluir  < mapa >
# incluir  < algoritmo >
# incluye  < math.h >
# incluye  < cstring >
# incluye  < TF1.h >
# incluye  < TH1.h >
# incluye  < TGraph.h >
# incluye  < TLegend.h >
# incluye  < TFile.h >
# incluye  < TDirectory.h >
# incluye  < TTree.h >
# incluye  < TEnv.h >
# incluye  < THStack.h >
# incluye  < TFile.h >
# incluye  < TTree.h >
# incluye  < TKey.h >
# incluye  < TCanvas.h >
# incluye  < TStyle.h >
# incluye  < TLatex.h >
# incluye  < TImage.h >
# incluye  < TLine.h >
# incluye  < TColor.h >
# incluye  < TROOT.h >
# incluye  < TH2F.h >
# incluye  < TMath.h >
# incluye  < TPaveText.h >
# include  < TMathText.h >
# incluye  < TFrame.h >
# incluye  < TArrow.h >
# incluye  < TGaxis.h >

// incluye el encabezado principal ubicado en el mismo directorio
# incluye  " Plotting.h "

// ######################## BANDERAS ###################### ######### //

// indicador de depuración, establecido en 1 para las comprobaciones
# definir  DEBUG  0

// indicador de rendimiento, establecido en 1 datos de impresión superior y rendimiento de MC
# definir  RENDIMIENTOS  0

// Bandera de señal normalizada, establecida en 1 para agregar señal normalizada a los gráficos (se puede utilizar para Higgs, SingleTop, ZPrime, SUSY)
# definir  NORMSIG  0

// guardar en la bandera pdf, por defecto los gráficos se guardan como png
# definir  SAVEPDF  1

// guardar en la bandera de formato raíz
# define  SAVEROOT  1

// ////////////////////////////////////////////////// //////////////////////////////////////////////
int  main ( int argc, char * argv []) {
  
  si (argc < 3 ) {
    std :: cout << " uso: ./plot [WBosonAnalysis, ZBosonAnalysis, TTbarAnalysis, SingleTopAnalysis, WZDiBosonAnalysis, ZZDiBosonAnalysis, HWWAnalysis, HZZAnalysis, ZTauTauAnalysis, HyyAnalysis, SUSYAnalysis, ZPrimeBoostedAnalysis] [ubicación de OutputDir_AnalysisName] " << std :: endl;
    std :: cout << " salida almacenada en un directorio \ ' histogramas \'  " << std :: endl;
    salida ( 1 );
  }
  
  Trazado * m = nuevo  Trazado ();
  
  m-> SetLumi ( 10064 ); // luminosidad configurada a mano en 10fb-1
  m-> SetOption (argv [ 1 ]);
  m-> SetInputLocation (argv [ 2 ]);
  opción de cadena = argv [ 1 ];

  
  // ejecutar el código de trazado principal
  m-> ejecutar ();
  
  eliminar m;
  return  0 ;
}
// /
Trazado :: Trazado () {
  lumi = 0 ;
}

// /
Trazado :: ~ Trazado () {
}

// /
 Trazado vacío :: SetLumi ( doble l) {
  lumi = l;
}

vacío  trazado :: SetOption (análisis std :: string) {
  opción = análisis;
}

vacío  trazado :: SetInputLocation (std :: string loc) {
  readname = loc;
}


// /
Void  Plotting :: run () {
  
  Descargo de responsabilidad ();
  
  getHistoSettings ();
  
  AtlasStyle ();
  
  WhichFiles ();
  
  readFiles ();
  
  makePlots ();
  
  volver ;
}

// /
void  Plotting :: Descargo de responsabilidad () {
  
  std :: cout << " \ n --------------------- DESCARGO DE RESPONSABILIDAD ------------------- - \ n " << std :: endl;
  std :: cout << "¡ Este software está destinado únicamente para uso educativo! " << std :: endl;
  std :: cout << "¡ Bajo ninguna circunstancia califica para reproducir resultados de análisis ATLAS reales o producir resultados publicables! " << std :: endl;
  std :: cout << " \ n ----------------------------------------- ----------- \ n " << std :: endl;
  
}

// /
 Trazado vacío :: AtlasStyle () {
  TStyle * atlasStyle = new  TStyle ( " ATLAS " , " Estilo Atlas " );
  Int_t icol = 0 ; // BLANCO
  atlasStyle-> SetFrameBorderMode (icol);
  atlasStyle-> SetFrameFillColor (icol);
  atlasStyle-> SetCanvasBorderMode (icol);
  atlasStyle-> SetCanvasColor (icol);
  atlasStyle-> SetPadBorderMode (icol);
  atlasStyle-> SetPadColor (icol);
  atlasStyle-> SetStatColor (icol);
  atlasStyle-> SetPaperSize ( 20 , 26 );
  atlasStyle-> SetPadTopMargin ( 0.05 );
  atlasStyle-> SetPadRightMargin ( 0.05 );
  atlasStyle-> SetPadBottomMargin ( 0.16 );
  atlasStyle-> SetPadLeftMargin ( 0.16 );
  atlasStyle-> SetTitleXOffset ( 1.4 );
  atlasStyle-> SetTitleYOffset ( 1.4 );
  Int_t font = 42 ; // Helvética
  Double_t tsize = 0.05 ;
  atlasStyle-> SetTextFont (fuente);
  atlasStyle-> SetTextSize (tsize);
  atlasStyle-> SetLabelFont (fuente, " x " );
  atlasStyle-> SetTitleFont (fuente, " x " );
  atlasStyle-> SetLabelFont (fuente, " y " );
  atlasStyle-> SetTitleFont (fuente, " y " );
  atlasStyle-> SetLabelFont (fuente, " z " );
  atlasStyle-> SetTitleFont (fuente, " z " );
  atlasStyle-> SetLabelSize (tsize, " x " );
  atlasStyle-> SetTitleSize (tsize, " x " );
  atlasStyle-> SetLabelSize (tsize, " y " );
  atlasStyle-> SetTitleSize (tsize, " y " );
  atlasStyle-> SetLabelSize (tsize, " z " );
  atlasStyle-> SetTitleSize (tsize, " z " );
  atlasStyle-> SetMarkerStyle ( 20 );
  atlasStyle-> SetMarkerSize ( 1.2 );
  atlasStyle-> SetHistLineWidth ( 2. );
  atlasStyle-> SetLineStyleString ( 2 , " [12 12] " ); // guiones postscript
  atlasStyle-> SetEndErrorSize ( 0. );
  atlasStyle-> SetOptTitle ( 0 );
  atlasStyle-> SetOptStat ( 0 );
  atlasStyle-> SetOptFit ( 0 );
  atlasStyle-> SetPadTickX ( 1 );
  atlasStyle-> SetPadTickY ( 1 );
  gROOT -> SetStyle ( " ATLAS " );
  gROOT -> ForceStyle ();
}

// /
 Trazado vacío :: ATLASLabel (Double_t x, Double_t y)
{
  TLatex l;
  l. SetNDC ();
  l. SetTextFont ( 72 );
  l. SetTextColor ( kBlack );
  l. SetTextSize ( 0.05 );  
  doble delx = 0,13 ; // 0.16
  l. DrawLatex (x, y, " ATLAS " );
  TLatex p; 
  pags. SetNDC ();
  pags. SetTextFont ( 42 );
  pags. SetTextColor ( kBlack );
  pags. SetTextSize ( 0.05 );  
  // p.DrawLatex (x + delx, y, "Datos abiertos");
  pags. DrawLatex (x + delx, y, " Datos abiertos preliminares " );
  // p.DrawLatex (x + delx, y, "Datos abiertos internos");

  volver ;
}

// /
void  Plotting :: WhichFiles () {
  // lee el archivo de entrada con los nombres de las muestras
  std :: string ifile;

  // opciones
  if (option. find ( " ZBosonAnalysis " )! = option. npos || option. find ( " TTbarAnalysis " )! = option. npos || option. find ( " WZDiBosonAnalysis " )! = option. npos || option. find ( " ZZDiBosonAnalysis " )! = Opción. Npos ) {ifile = " inputfiles / Files_base.txt " ;}
  if (opción. find ( " WBosonAnalysis " )! = opción. npos || opción. find ( " SingleTopAnalysis " )! = opción. npos ) {ifile = " inputfiles / Files_WBoson.txt " ;}
  if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {ifile = " inputfiles / Files_ZPrime.txt " ;}
  if (option. find ( " HWWAnalysis " )! = option. npos ) {ifile = " inputfiles / Files_HWW.txt " ;}
  if (option. find ( " SUSYAnalysis " )! = option. npos ) {ifile = " inputfiles / Files_SUSY.txt " ;}
  if (option. find ( " HZZAnalysis " )! = option. npos ) {ifile = " inputfiles / Files_HZZ.txt " ;}
  if (option. find ( " ZTauTauAnalysis " )! = option. npos ) {ifile = " inputfiles / Files_ZTauTau.txt " ;}
  if (option. find ( " HyyAnalysis " )! = option. npos ) {ifile = " inputfiles / Files_Hyy.txt " ;}
 
  std :: cout << " Análisis: " << opción << " , leyendo la entrada de: " << ifile. c_str () << "  \ n  " << std :: endl;

  ifstream input (ifile. c_str ());
  std :: línea de cadena;
  while ( getline (entrada, línea)) {
    if (línea. buscar ( " # " )! = línea. npos ) continuar ; // un # es un comentario y no se lee
    std :: nombre de la cadena, xsec, sumw, eff;
    istringstream linestream (línea);
    getline (línea lineal, nombre, ' | ' );
    getline (linestream, xsec, ' | ' );
    getline (linestream, sumw, ' | ' );
    getline (línea lineal, ef);
    if (DEBUG) cout << nombre << "  " << xsec << "  " << sumw << "  " << eff << endl;
    flotante sumw_eff = atof (sumw. c_str ()) * atof (eff. c_str ());
    SF [nombre] = std :: make_pair ( atof (xsec. C_str ()), sumw_eff);    
    
  }
  volver ;
}

// /
vacío  trazado :: readFiles () {
  std :: cout << " Leyendo archivos de: " << readname << "  \ n  " << std :: endl;
  
  if (option. find ( " WBosonAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando WBosonAnalysis ===== " << std :: endl;
  }
  if (option. find ( " ZBosonAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando ZBosonAnalysis ===== " << std :: endl;
  }
  if (option. find ( " TTbarAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando TTbarAnalysis ===== " << std :: endl;
  }
  if (option. find ( " SingleTopAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando SingleTopAnalysis ===== " << std :: endl;
  }
  if (option. find ( " HyyAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando HyyAnalysis ===== " << std :: endl;
  }
  if (option. find ( " WZDiBosonAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando WZDiBosonAnalysis ===== " << std :: endl;
  }
  if (option. find ( " ZZDiBosonAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando ZZDiBosonAnalysis ===== " << std :: endl;
  }
  if (option. find ( " HWWAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando HWWAnalysis ===== " << std :: endl;
  }
  if (option. find ( " HZZAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando HZZAnalysis ===== " << std :: endl;
  }
  if (option. find ( " ZTauTauAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando ZTauTauAnalysis ===== " << std :: endl;
  }
  if (option. find ( " SUSYAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando SUSYAnalysis ===== " << std :: endl;
  }
  if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {
    std :: cout << " ===== procesando ZPrimeBoostedAnalysis ===== " << std :: endl;
  }

  std :: cout << " \ n " << std :: endl;

  std :: mapa <std :: cadena, std :: par < doble , doble >> :: const_iterator SFiter;
  para (SFiter = SF. begin (); SFiter! = SF. end (); SFiter ++) {
    std :: string readme = readname + " / " + SFiter-> first + " .root " ;
    if (DEBUG) std :: cout << " Leyendo archivo: " << readme << std :: endl;
    TFile * file = TFile :: Open (readme. C_str (), " READ " );
    
    createHistoSet (archivo, SFiter-> primero );
    
    // aplicar factores de escala: la escala se realiza calculando la luminosidad de la muestra a través de xsec / (sumw * red_eff) y multiplicando la luminosidad objetivo
    if ( std :: strstr ((SFiter-> first ). c_str (), " data " ) == NULL ) {
      std :: vector <std :: string> v_n; v_n. claro ();
      std :: string n = SFiter-> primero ;
      v_n. push_back (n);
      for ( unsigned  int i = 0 ; i <v_n. size (); ++ i) {
        std :: map <std :: string, TH1F *> :: const_iterator fIter = histo [v_n [i]]. comenzar ();
        std :: map <std :: string, TH1F *> :: const_iterator lIter = histo [v_n [i]]. fin ();
        doble scf = 1 ;
	scf = (lumi * SFiter-> segundo . primero ) / SFiter-> segundo . segundo ;
        for (; fIter ! = lIter; ++ fIter ) {
	  if (DEBUG) std :: cout << " Histograma de escala: " << fIter -> first << " por un factor de: " << scf << std :: endl;
	  fIter -> segundo -> Escala (scf);

          // Desbordamiento de MC
	  if ( std :: strstr (( después -> primero ). c_str (), " cuatro_lep " ) == NULL )
          if ( abs ( después -> segundo -> GetBinContent ( después -> segundo -> GetNbinsX () + 1 ))> 0 ) {
            fIter -> segundo -> AddBinContent ( fIter -> segundo -> GetNbinsX (), fIter -> segundo -> GetBinContent ( fIter -> segundo -> GetNbinsX () + 1 ));
          }

        }
      }
    }
    
  }
  volver ;
}

// /
vacío  trazado :: createHistoSet (TFile * archivo, std :: string proc) {
  
  std :: vector <HistoHandler *> :: iterator fIter = hset. comenzar ();
  std :: vector <HistoHandler *> :: iterator lIter = hset. fin ();
  
  for (; fIter ! = lIter; ++ fIter ) {
    std :: cadena n;
    n = (* fIter ) -> GetName ();
    if (DEBUG) cout << " leyendo histograma: " << n << endl;
    createHistogram (archivo, n, proc);  
  }
  
  volver ;
}


// /
void  Plotting :: createHistogram (TFile * archivo, std :: string hname, std :: string proc) {
  
  histo [proc] [hname] = (TH1F *) archivo-> Get (hname. c_str ());
  
  volver ;
}

// /
 Trazado vacío :: makePlots () {
  
  TCanvas * c;
  c = nuevo  TCanvas ( " c " , " c " , 700 , 750 );
  TPad * pad0; // superior
  TPad * pad1; // inferior
  TPad * padX; // máscara
  TPad * pad2X; // máscara

  pad0 = nuevo  TPad ( " pad0 " , " pad0 " , 0 , 0.29 , 1 , 1 , 0 , 0 , 0 );
  pad0-> SetTickx ( falso );
  pad0-> SetTicky ( falso );
  pad0-> SetTopMargin ( 0.05 );
  pad0-> SetBottomMargin ( 0 );
  pad0-> SetLeftMargin ( 0.14 );
  pad0-> SetRightMargin ( 0.05 );
  pad0-> SetFrameBorderMode ( 0 );
  pad0-> SetTopMargin ( 0.06 );

  pad1 = nuevo  TPad ( " pad1 " , " pad1 " , 0 , 0 , 1 , 0.29 , 0 , 0 , 0 );
  pad1-> SetTickx ( falso );
  pad1-> SetTicky ( falso );
  pad1-> SetTopMargin ( 0.0 );
  pad1-> SetBottomMargin ( 0.5 );
  pad1-> SetLeftMargin ( 0.14 );
  pad1-> SetRightMargin ( 0.05 );
  pad1-> SetFrameBorderMode ( 0 );

 
  padX = nuevo  TPad ( " pad1 " , " pad1 " , 0.08 , 0.27 , 0.135 , 0.29 , 0 , 0 , 0 );
  padX-> SetTickx ( falso ); padX-> SetTicky ( falso ); padX-> SetTopMargin ( 0.0 );
  padX-> SetBottomMargin ( 0.5 ); padX-> SetLeftMargin ( 0.14 ); padX-> SetRightMargin ( 0.05 ); padX-> SetFrameBorderMode ( 0 );

  pad2X = nuevo  TPad ( " pad1 " , " pad1 " , 0.08 , 0.132 , 0.135 , 0.16 , 0 , 0 , 0 );
  pad2X-> SetTickx ( falso ); pad2X-> SetTicky ( falso ); pad2X-> SetTopMargin ( 0.0 );
  pad2X-> SetBottomMargin ( 0.5 ); pad2X-> SetLeftMargin ( 0.14 ); pad2X-> SetRightMargin ( 0.05 ); pad2X-> SetFrameBorderMode ( 0 );


  pad1-> Dibujar ();
  pad0-> Dibujar ();
  padX-> Dibujar ();
  if (! (option. find ( " HyyAnalysis " )! = option. npos )) pad2X-> Draw ();

  pad0-> cd ();
  
  // ////////////////////////////////////////////////// ///////////////////////
  // creamos los mapas de los histogramas para cada muestra

  // datos
  std :: map <std :: string, TH1F *> datos; 
  
  // Higgs a WW
  std :: mapa <std :: cadena, TH1F *> ggH125_WW2lep;
  std :: mapa <std :: cadena, TH1F *> VBFH125_WW2lep;

  // Higgs a ZZ
  std :: mapa <std :: cadena, TH1F *> ggH125_ZZ4lep;
  estándar :: mapa <estándar :: cadena, TH1F *> ZH125_ZZ4lep;
  std :: mapa <std :: cadena, TH1F *> WH125_ZZ4lep;
  std :: mapa <std :: cadena, TH1F *> VBFH125_ZZ4lep;

  // Higgs a fotones (yy)
  std :: map <std :: string, TH1F *> ggH125_gamgam;
  std :: mapa <std :: string, TH1F *> ttH125_gamgam;
  std :: mapa <std :: cadena, TH1F *> VBFH125_gamgam;
  std :: map <std :: string, TH1F *> WH125_gamgam;
  std :: mapa <std :: cadena, TH1F *> ZH125_gamgam;

  // Muestra SUSY (par de durmientes)
  estándar :: mapa <estándar :: cadena, TH1F *> slep600DM300;

  // Zprime con Z '(1 TeV) -> tt muestra
  std :: map <std :: string, TH1F *> ZPrime1000;

  // producción predeterminada de pares superiores, solo desintegraciones individuales + dileptones de ttbar
  std :: mapa <std :: cadena, TH1F *> ttbar_lep;   
  
  // Muestras de Powheg de bosón Z (una muestra por sabor de descomposición) = no se supone que describa regiones de multiplicidad de chorro grandes
  std :: mapa <std :: string, TH1F *> Zee;
  std :: map <std :: string, TH1F *> Zmumu;
  std :: mapa <std :: cadena, TH1F *> Ztautau;
    
  // Diboson Sherpa (WW, WZ, ZZ)
  std :: mapa <std :: cadena, TH1F *> WlvZqq; 
  std :: mapa <std :: cadena, TH1F *> WplvWmqq; 
  std :: map <std :: cadena, TH1F *> WpqqWmlv; 
  std :: mapa <std :: cadena, TH1F *> ZqqZll; 
  std :: mapa <std :: cadena, TH1F *> WqqZll; 
  std :: mapa <std :: cadena, TH1F *> llll;
  std :: mapa <std :: cadena, TH1F *> lllv;
  std :: map <std :: string, TH1F *> llvv;
  std :: mapa <std :: cadena, TH1F *> lvvv;
  
  // W + jets Muestras de Powheg (una muestra por carga y sabor de descomposición) = no se supone que describa regiones grandes de multiplicidad de chorros
  std :: mapa <std :: cadena, TH1F *> Wplusenu;
  std :: mapa <std :: cadena, TH1F *> Wplusmunu;
  std :: mapa <std :: cadena, TH1F *> Wplustaunu;
  std :: map <std :: string, TH1F *> Wminusenu;
  std :: map <std :: string, TH1F *> Wminusmunu;
  std :: mapa <std :: cadena, TH1F *> Wminustaunu;
  
  // parte superior simple (t, s, tW-canales)
  std :: map <std :: string, TH1F *> single_top_tchan;
  std :: map <std :: string, TH1F *> single_antitop_tchan;
  std :: map <std :: string, TH1F *> single_top_wtchan;
  std :: mapa <std :: cadena, TH1F *> single_antitop_wtchan;
  std :: map <std :: string, TH1F *> single_top_schan;
  std :: map <std :: string, TH1F *> single_antitop_schan;
  
 
  // V + jets Muestras Sherpa (que contienen desintegraciones leptónicas de bosones W o Z con jets asociados) = describe una multiplicidad de chorros grandes, generada con diferentes requisitos de hadrones b y c, es necesario fusionarlos todos en uno (hecho más tarde )
  std :: map <std :: string, TH1F *> Wenu_PTV0_70_BFilter; std :: mapa <std :: string, TH1F *> Wenu_PTV0_70_CFilterBVeto; std :: mapa <std :: string, TH1F *> Wenu_PTV0_70_CVetoBVeto; std :: mapa <std :: string, TH1F *> Wenu_PTV1000; std :: mapa <std :: cadena, TH1F *> Wenu_PTV140_280_BFilter; estándar :: mapa <estándar :: cadena, TH1F *> Wenu_PTV140_280_CFilterBVeto; std :: mapa <std :: string, TH1F *> Wenu_PTV140_280_CVetoBVeto; std :: map <std :: string, TH1F *> Wenu_PTV280_500_BFilter; std :: mapa <std :: string, TH1F *> Wenu_PTV280_500_CFilterBVeto; std :: map <std :: string, TH1F *> Wenu_PTV280_500_CVetoBVeto; std :: mapa <std :: string, TH1F *> Wenu_PTV500_1000; std :: mapa <std :: cadena, TH1F *> Wenu_PTV70_140_BFilter; std :: mapa <std :: string, TH1F *> Wenu_PTV70_140_CFilterBVeto; std :: mapa <std :: string, TH1F *> Wenu_PTV70_140_CVetoBVeto; std :: mapa <std :: cadena, TH1F *> Wmunu_PTV0_70_BFilter; std :: map <std :: string, TH1F *> Wmunu_PTV0_70_CFilterBVeto; std :: map <std :: string, TH1F *> Wmunu_PTV0_70_CVetoBVeto; std :: map <std :: string, TH1F *> Wmunu_PTV1000; std :: map <std :: string, TH1F *> Wmunu_PTV140_280_BFilter; std :: map <std :: string, TH1F *> Wmunu_PTV140_280_CFilterBVeto; std :: map <std :: string, TH1F *> Wmunu_PTV140_280_CVetoBVeto; std :: mapa <std :: cadena, TH1F *> Wmunu_PTV280_500_BFilter; std :: mapa <std :: string, TH1F *> Wmunu_PTV280_500_CFilterBVeto; std :: map <std :: string, TH1F *> Wmunu_PTV280_500_CVetoBVeto; std :: map <std :: string, TH1F *> Wmunu_PTV500_1000; std :: map <std :: string, TH1F *> Wmunu_PTV70_140_BFilter; std :: mapa <std :: string, TH1F *> Wmunu_PTV70_140_CFilterBVeto; std :: mapa <std :: cadena, TH1F *> Wmunu_PTV70_140_CVetoBVeto; std :: map <std :: cadena, TH1F *> Wtaunu_PTV0_70_BFilter; std :: map <std :: string, TH1F *> Wtaunu_PTV0_70_CFilterBVeto; std :: map <std :: string, TH1F *> Wtaunu_PTV0_70_CVetoBVeto; std :: map <std :: string, TH1F *> Wtaunu_PTV1000; std :: map <std :: string, TH1F *> Wtaunu_PTV140_280_BFilter; std :: map <std :: string, TH1F *> Wtaunu_PTV140_280_CFilterBVeto; std :: map <std :: string, TH1F *> Wtaunu_PTV140_280_CVetoBVeto; std :: map <std :: string, TH1F *> Wtaunu_PTV280_500_BFilter; std :: map <std :: string, TH1F *> Wtaunu_PTV280_500_CFilterBVeto; std :: map <std :: string, TH1F *> Wtaunu_PTV280_500_CVetoBVeto; std :: mapa <std :: cadena, TH1F *> Wtaunu_PTV500_1000; std :: map <std :: string, TH1F *> Wtaunu_PTV70_140_BFilter; std :: map <std :: string, TH1F *> Wtaunu_PTV70_140_CFilterBVeto; std :: map <std :: string, TH1F *> Wtaunu_PTV70_140_CVetoBVeto; std :: mapa <std: : cadena, TH1F *> Zee_PTV0_70_BFilter; std :: map <std :: string, TH1F *> Zee_PTV0_70_CFilterBVeto; std :: map <std :: string, TH1F *> Zee_PTV0_70_CVetoBVeto; std :: map <std :: string, TH1F *> Zee_PTV1000; std :: map <std :: string, TH1F *> Zee_PTV140_280_BFilter; std :: mapa <std :: string, TH1F *> Zee_PTV140_280_CFilterBVeto; std :: map <std :: string, TH1F *> Zee_PTV140_280_CVetoBVeto; std :: map <std :: string, TH1F *> Zee_PTV280_500_BFilter; std :: map <std :: string, TH1F *> Zee_PTV280_500_CFilterBVeto; std :: map <std :: string, TH1F *> Zee_PTV280_500_CVetoBVeto; std :: map <std :: string, TH1F *> Zee_PTV500_1000; std :: mapa <std :: cadena, TH1F *> Zee_PTV70_140_BFilter; std :: map <std :: string, TH1F *> Zee_PTV70_140_CFilterBVeto; std :: map <std :: string, TH1F *> Zee_PTV70_140_CVetoBVeto; std :: map <std :: cadena, TH1F *> Zmumu_PTV0_70_BFilter; std :: map <std :: string, TH1F *> Zmumu_PTV0_70_CFilterBVeto; std :: map <std :: string, TH1F *> Zmumu_PTV0_70_CVetoBVeto; std :: map <std :: string, TH1F *> Zmumu_PTV1000; std :: mapa <std :: cadena, TH1F *> Zmumu_PTV140_280_BFilter; std :: map <std :: string, TH1F *> Zmumu_PTV140_280_CFilterBVeto; std :: map <std :: string, TH1F *> Zmumu_PTV140_280_CVetoBVeto; std :: mapa <std :: cadena, TH1F *> Zmumu_PTV280_500_BFilter; std :: mapa <std :: string, TH1F *> Zmumu_PTV280_500_CFilterBVeto; std :: mapa <std :: string, TH1F *> Zmumu_PTV280_500_CVetoBVeto; estándar :: mapa <estándar :: cadena, TH1F *> Zmumu_PTV500_1000; std :: map <std :: string, TH1F *> Zmumu_PTV70_140_BFilter; std :: map <std :: string, TH1F *> Zmumu_PTV70_140_CFilterBVeto; std :: mapa <std :: string, TH1F *> Zmumu_PTV70_140_CVetoBVeto; std :: map <std :: cadena, TH1F *> Ztautau_PTV0_70_BFilter; std :: map <std :: string, TH1F *> Ztautau_PTV0_70_CFilterBVeto; std :: map <std :: string, TH1F *> Ztautau_PTV0_70_CVetoBVeto; std :: map <std :: string, TH1F *> Ztautau_PTV1000; std :: mapa <std :: cadena, TH1F *> Ztautau_PTV140_280_BFilter; std :: mapa <std :: string, TH1F *> Ztautau_PTV140_280_CFilterBVeto; std :: map <std :: string, TH1F *> Ztautau_PTV140_280_CVetoBVeto; std :: map <std :: string, TH1F *> Ztautau_PTV280_500_BFilter; std :: map <std :: string, TH1F *> Ztautau_PTV280_500_CFilterBVeto; std :: map <std :: string, TH1F *> Ztautau_PTV280_500_CVetoBVeto; std :: mapa <std :: cadena, TH1F *> Ztautau_PTV500_1000; std :: mapa <std :: cadena, TH1F *> Ztautau_PTV70_140_BFilter; std :: map <std :: string, TH1F *> Ztautau_PTV70_140_CFilterBVeto; std :: map <std :: string, TH1F *> Ztautau_PTV70_140_CVetoBVeto;
  
  
  // ////////////////////////////////////////////////// ///////////////////////
  // Lectura real de los archivos de entrada
  // Los nombres deben ser los mismos que en Archivos _ ***. Txt

  // leer datos
  datos = histo [ " datos " ];
  
  // leer H-> ZZ
  if (option. find ( " HZZAnalysis " )! = option. npos ) {
    ggH125_ZZ4lep = histo [ " ggH125_ZZ4lep " ];
    ZH125_ZZ4lep = histo [ " ZH125_ZZ4lep " ];
    WH125_ZZ4lep = histo [ " WH125_ZZ4lep " ];
    VBFH125_ZZ4lep = histo [ " VBFH125_ZZ4lep " ];
  }
  
  // leer H-> WW (se descuidan las contribuciones de WH y ZH muy pequeñas)
  if (option. find ( " HWWAnalysis " )! = option. npos ) {
    ggH125_WW2lep = histo [ " ggH125_WW2lep " ];
    VBFH125_WW2lep = histo [ " VBFH125_WW2lep " ];
  }

  // leer H-> yy
  if (option. find ( " HyyAnalysis " )! = option. npos ) {
    ggH125_gamgam = histo [ " ggH125_gamgam " ];
    ttH125_gamgam = histo [ " ttH125_gamgam " ] ;;
    VBFH125_gamgam = histo [ " VBFH125_gamgam " ] ;;
    WH125_gamgam = histo [ " WH125_gamgam " ] ;;
    ZH125_gamgam = histo [ " ZH125_gamgam " ] ;;
  }

  // leyendo ttbar
  ttbar_lep = histo [ " ttbar_lep " ];
  
  // lectura de muestras de chorros Powheg Z +, utilizadas en análisis HZZ, ZZDiBoson, SingleTop, TTbar, WBoson, ZPrimeBoosted, ZBoson, HWW, WZDiBoson ...
  if (option. find ( " HZZAnalysis " )! = option. npos || option. find ( " ZZDiBosonAnalysis " )! = option. npos || option. find ( " WZDiBosonAnalysis " )! = option. npos || option. find ( " HWWAnalysis " )! = opción. npos opción ||. encontrar ( " ZBosonAnalysis " )! = opción. npos opción ||. encontrar ( "ZPrimeBoostedAnalysis " )! = Opción. Npos opción ||. Encontrar ( " WBosonAnalysis " )! = Opción. Npos opción ||. Encontrar ( " TTbarAnalysis " )! = Opción. Npos opción ||. Encontrar ( " SingleTopAnalysis " )! = opción. npos )
    {
      Zee = histo [ " Zee " ];
      Zmumu = histo [ " Zmumu " ];
      Ztautau = histo [ " Ztautau " ];
    }
  
  // lectura de muestras de jets Powheg W +, utilizadas en análisis HZZ, HWW, ZZDiBoson, WZDiBoson, TTbar, ZBoson, SUSY ...
  if (option. find ( " ZBosonAnalysis " )! = option. npos || option. find ( " TTbarAnalysis " )! = option. npos || option. find ( " WZDiBosonAnalysis " )! = option. npos || option. find ( " ZZDiBosonAnalysis " )! = opción. npos opción ||. encontrar ( " HWWAnalysis " )! = opción. npos opción ||. encontrar ( "HZZAnalysis " )! = Opción. Npos )
    {
      Wplusenu = histo [ " Wplusenu " ];
      Wplusmunu = histo [ " Wplusmunu " ];
      Wplustaunu = histo [ " Wplustaunu " ];  
      Wminusenu = histo [ " Wminusenu " ];
      Wminusmunu = histo [ " Wminusmunu " ];
      Wminustaunu = histo [ " Wminustaunu " ];
    }
  
  // lectura de muestras de jets Sherpa W +, utilizadas en análisis de WBoson, ZTauTau, SingleTop, ZPrimeBoosted ...
  if (option. find ( " SUSYAnalysis " )! = option. npos || option. find ( " ZPrimeBoostedAnalysis " )! = option. npos || option. find ( " SingleTopAnalysis " )! = option. npos || option. find ( " ZTauTauAnalysis " )! = opción. npos opción ||. encontrar ( " WBosonAnalysis " )! = opción. ONL )
    {
      Wenu_PTV0_70_BFilter = histo [ " Wenu_PTV0_70_BFilter " ];
      Wenu_PTV0_70_CFilterBVeto = histo [ " Wenu_PTV0_70_CFilterBVeto " ];
      Wenu_PTV0_70_CVetoBVeto = histo [ " Wenu_PTV0_70_CVetoBVeto " ];
      Wenu_PTV1000 = histo [ " Wenu_PTV1000 " ];
      Wenu_PTV140_280_BFilter = histo [ " Wenu_PTV140_280_BFilter " ];
      Wenu_PTV140_280_CFilterBVeto = histo [ " Wenu_PTV140_280_CFilterBVeto " ];
      Wenu_PTV140_280_CVetoBVeto = histo [ " Wenu_PTV140_280_CVetoBVeto " ];
      Wenu_PTV280_500_BFilter = histo [ " Wenu_PTV280_500_BFilter " ];
      Wenu_PTV280_500_CFilterBVeto = histo [ " Wenu_PTV280_500_CFilterBVeto " ];
      Wenu_PTV280_500_CVetoBVeto = histo [ " Wenu_PTV280_500_CVetoBVeto " ];
      Wenu_PTV500_1000 = histo [ " Wenu_PTV500_1000 " ];
      Wenu_PTV70_140_BFilter = histo [ " Wenu_PTV70_140_BFilter " ];
      Wenu_PTV70_140_CFilterBVeto = histo [ " Wenu_PTV70_140_CFilterBVeto " ];
      Wenu_PTV70_140_CVetoBVeto = histo [ " Wenu_PTV70_140_CVetoBVeto " ];
      Wmunu_PTV0_70_BFilter = histo [ " Wmunu_PTV0_70_BFilter " ];
      Wmunu_PTV0_70_CFilterBVeto = histo [ " Wmunu_PTV0_70_CFilterBVeto " ];
      Wmunu_PTV0_70_CVetoBVeto = histo [ " Wmunu_PTV0_70_CVetoBVeto " ];
      Wmunu_PTV1000 = histo [ " Wmunu_PTV1000 " ];
      Wmunu_PTV140_280_BFilter = histo [ " Wmunu_PTV140_280_BFilter " ];
      Wmunu_PTV140_280_CFilterBVeto = histo [ " Wmunu_PTV140_280_CFilterBVeto " ];
      Wmunu_PTV140_280_CVetoBVeto = histo [ " Wmunu_PTV140_280_CVetoBVeto " ];
      Wmunu_PTV280_500_BFilter = histo [ " Wmunu_PTV280_500_BFilter " ];
      Wmunu_PTV280_500_CFilterBVeto = histo [ " Wmunu_PTV280_500_CFilterBVeto " ];
      Wmunu_PTV280_500_CVetoBVeto = histo [ " Wmunu_PTV280_500_CVetoBVeto " ];
      Wmunu_PTV500_1000 = histo [ " Wmunu_PTV500_1000 " ];
      Wmunu_PTV70_140_BFilter = histo [ " Wmunu_PTV70_140_BFilter " ];
      Wmunu_PTV70_140_CFilterBVeto = histo [ " Wmunu_PTV70_140_CFilterBVeto " ];
      Wmunu_PTV70_140_CVetoBVeto = histo [ " Wmunu_PTV70_140_CVetoBVeto " ];
      Wtaunu_PTV0_70_BFilter = histo [ " Wtaunu_PTV0_70_BFilter " ];
      Wtaunu_PTV0_70_CFilterBVeto = histo [ " Wtaunu_PTV0_70_CFilterBVeto " ];
      Wtaunu_PTV0_70_CVetoBVeto = histo [ " Wtaunu_PTV0_70_CVetoBVeto " ];
      Wtaunu_PTV1000 = histo [ " Wtaunu_PTV1000 " ];
      Wtaunu_PTV140_280_BFilter = histo [ " Wtaunu_PTV140_280_BFilter " ];
      Wtaunu_PTV140_280_CFilterBVeto = histo [ " Wtaunu_PTV140_280_CFilterBVeto " ];
      Wtaunu_PTV140_280_CVetoBVeto = histo [ " Wtaunu_PTV140_280_CVetoBVeto " ];
      Wtaunu_PTV280_500_BFilter = histo [ " Wtaunu_PTV280_500_BFilter " ];
      Wtaunu_PTV280_500_CFilterBVeto = histo [ " Wtaunu_PTV280_500_CFilterBVeto " ];
      Wtaunu_PTV280_500_CVetoBVeto = histo [ " Wtaunu_PTV280_500_CVetoBVeto " ];
      Wtaunu_PTV500_1000 = histo [ " Wtaunu_PTV500_1000 " ];
      Wtaunu_PTV70_140_BFilter = histo [ " Wtaunu_PTV70_140_BFilter " ];
      Wtaunu_PTV70_140_CFilterBVeto = histo [ " Wtaunu_PTV70_140_CFilterBVeto " ];
      Wtaunu_PTV70_140_CVetoBVeto = histo [ " Wtaunu_PTV70_140_CVetoBVeto " ];
    }
  
  // lectura de muestras de jets Sherpa Z +, utilizadas en análisis ZTaTau y SUSY
  if (option. find ( " ZTauTauAnalysis " )! = option. npos || option. find ( " SUSYAnalysis " )! = option. npos )
    {
      Zee_PTV0_70_BFilter = histo [ " Zee_PTV0_70_BFilter " ];
      Zee_PTV0_70_CFilterBVeto = histo [ " Zee_PTV0_70_CFilterBVeto " ];
      Zee_PTV0_70_CVetoBVeto = histo [ " Zee_PTV0_70_CVetoBVeto " ];
      Zee_PTV1000 = histo [ " Zee_PTV1000 " ];
      Zee_PTV140_280_BFilter = histo [ " Zee_PTV140_280_BFilter " ];
      Zee_PTV140_280_CFilterBVeto = histo [ " Zee_PTV140_280_CFilterBVeto " ];
      Zee_PTV140_280_CVetoBVeto = histo [ " Zee_PTV140_280_CVetoBVeto " ];
      Zee_PTV280_500_BFilter = histo [ " Zee_PTV280_500_BFilter " ];
      Zee_PTV280_500_CFilterBVeto = histo [ " Zee_PTV280_500_CFilterBVeto " ];
      Zee_PTV280_500_CVetoBVeto = histo [ " Zee_PTV280_500_CVetoBVeto " ];
      Zee_PTV500_1000 = histo [ " Zee_PTV500_1000 " ];
      Zee_PTV70_140_BFilter = histo [ " Zee_PTV70_140_BFilter " ];
      Zee_PTV70_140_CFilterBVeto = histo [ " Zee_PTV70_140_CFilterBVeto " ];
      Zee_PTV70_140_CVetoBVeto = histo [ " Zee_PTV70_140_CVetoBVeto " ];
      Zmumu_PTV0_70_BFilter = histo [ " Zmumu_PTV0_70_BFilter " ];
      Zmumu_PTV0_70_CFilterBVeto = histo [ " Zmumu_PTV0_70_CFilterBVeto " ];
      Zmumu_PTV0_70_CVetoBVeto = histo [ " Zmumu_PTV0_70_CVetoBVeto " ];
      Zmumu_PTV1000 = histo [ " Zmumu_PTV1000 " ];
      Zmumu_PTV140_280_BFilter = histo [ " Zmumu_PTV140_280_BFilter " ];
      Zmumu_PTV140_280_CFilterBVeto = histo [ " Zmumu_PTV140_280_CFilterBVeto " ];
      Zmumu_PTV140_280_CVetoBVeto = histo [ " Zmumu_PTV140_280_CVetoBVeto " ];
      Zmumu_PTV280_500_BFilter = histo [ " Zmumu_PTV280_500_BFilter " ];
      Zmumu_PTV280_500_CFilterBVeto = histo [ " Zmumu_PTV280_500_CFilterBVeto " ];
      Zmumu_PTV280_500_CVetoBVeto = histo [ " Zmumu_PTV280_500_CVetoBVeto " ];
      Zmumu_PTV500_1000 = histo [ " Zmumu_PTV500_1000 " ];
      Zmumu_PTV70_140_BFilter = histo [ " Zmumu_PTV70_140_BFilter " ];
      Zmumu_PTV70_140_CFilterBVeto = histo [ " Zmumu_PTV70_140_CFilterBVeto " ];
      Zmumu_PTV70_140_CVetoBVeto = histo [ " Zmumu_PTV70_140_CVetoBVeto " ];
      Ztautau_PTV0_70_BFilter = histo [ " Ztautau_PTV0_70_BFilter " ];
      Ztautau_PTV0_70_CFilterBVeto = histo [ " Ztautau_PTV0_70_CFilterBVeto " ];
      Ztautau_PTV0_70_CVetoBVeto = histo [ " Ztautau_PTV0_70_CVetoBVeto " ];
      Ztautau_PTV1000 = histo [ " Ztautau_PTV1000 " ];
      Ztautau_PTV140_280_BFilter = histo [ " Ztautau_PTV140_280_BFilter " ];
      Ztautau_PTV140_280_CFilterBVeto = histo [ " Ztautau_PTV140_280_CFilterBVeto " ];
      Ztautau_PTV140_280_CVetoBVeto = histo [ " Ztautau_PTV140_280_CVetoBVeto " ];
      Ztautau_PTV280_500_BFilter = histo [ " Ztautau_PTV280_500_BFilter " ];
      Ztautau_PTV280_500_CFilterBVeto = histo [ " Ztautau_PTV280_500_CFilterBVeto " ];
      Ztautau_PTV280_500_CVetoBVeto = histo [ " Ztautau_PTV280_500_CVetoBVeto " ];
      Ztautau_PTV500_1000 = histo [ " Ztautau_PTV500_1000 " ];
      Ztautau_PTV70_140_BFilter = histo [ " Ztautau_PTV70_140_BFilter " ];
      Ztautau_PTV70_140_CFilterBVeto = histo [ " Ztautau_PTV70_140_CFilterBVeto " ];
      Ztautau_PTV70_140_CVetoBVeto = histo [ " Ztautau_PTV70_140_CVetoBVeto " ];
    }
  
  
  // lectura de muestras de dibosón, utilizadas en todos los análisis
  WlvZqq = histo [ " WlvZqq " ];
  WplvWmqq = histo [ " WplvWmqq " ];
  WpqqWmlv = histo [ " WpqqWmlv " ];
  ZqqZll = histo [ " ZqqZll " ];
  WqqZll = histo [ " WqqZll " ];
  llll = histo [ " llll " ];
  lllv = histo [ " lllv " ];
  llvv = histo [ " llvv " ];
  lvvv = histo [ " lvvv " ];
  
  // muestra especial de SUSY
  if (option. find ( " SUSYAnalysis " )! = option. npos )
    {
      slep600DM300 = histo [ " slep600DM300 " ];
    }
 
  // muestra especial de Zprime
  if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {
      ZPrime1000 = histo [ " ZPrime1000_tt " ];
  }
  
  // lectura de muestras superiores únicas, utilizadas en todos los análisis
  single_top_tchan = histo [ " single_top_tchan " ];
  single_antitop_tchan = histo [ " single_antitop_tchan " ];
  single_top_wtchan = histo [ " single_top_wtchan " ];
  single_antitop_wtchan = histo [ " single_antitop_wtchan " ];
  single_top_schan = histo [ " single_top_schan " ];
  single_antitop_schan = histo [ " single_antitop_schan " ];  
  

  // ////////////////////////////////////////////////// ///////////////////////
  // Finalmente, la parte de trazado comienza aquí
  
  std :: map <std :: string, TH1F *> :: const_iterator fIter ;
  std :: map <std :: string, TH1F *> :: const_iterator lIter;
  fIter = datos. comenzar (); lIter = datos. fin ();

  // iterador sobre los nombres de los histogramas por archivo
  for (; fIter ! = lIter; ++ fIter ) {
    
    std :: cout << " Trazando histograma: " << fIter -> first << std :: endl;
    
    // estilo de datos
    fIter -> segundo -> SetMarkerStyle ( 20 );
    fIter -> segundo -> SetMarkerColor ( kBlack );
    fIter -> segundo -> SetMarkerSize ( 1.2 );
    fIter -> segundo -> SetLineWidth ( 2 );
    fIter -> segundo -> SetMinimum ( 0.1 );
    gStyle -> SetEndErrorSize ( 1. );
    TGaxis :: SetMaxDigits ( 4 ); // dígitos máximos en el título del eje Y
    // algunas opciones para Hyy
    if (opción. encontrar ( " HyyAnalysis " )! = opción. npos ) TGaxis :: SetMaxDigits ( 3 );
    fIter -> segundo -> GetYaxis () -> SetTitleOffset ( 1.2 );
    if (! (option. find ( " HyyAnalysis " )! = option. npos ))   fIter -> second -> Draw ( " E1 " );
    if (option. find ( " HyyAnalysis " )! = option. npos ) {
      fIter -> segundo -> Dibujar ( " E " );
      gStyle -> SetEndErrorSize ( 0. );
      gStyle -> SetErrorX ( 0.0 );
    }

    // crea histogramas y fusiona varios MC en ellos
    // general
    TH1F * dibosón = nuevo  TH1F ();
    TH1F * W = nuevo  TH1F ();
    TH1F * Z = nuevo  TH1F ();
    TH1F * ttbar = nuevo  TH1F ();
    TH1F * parada = nuevo  TH1F ();

    // especial
    TH1F * V = nuevo  TH1F ();
    TH1F * W_Z = nuevo  TH1F ();
    TH1F * Z_Z = nuevo  TH1F ();
    TH1F * WWZ = nuevo  TH1F ();
    TH1F * VV = nuevo  TH1F ();
    TH1F * arriba = nuevo  TH1F ();
    TH1F * topV = nuevo  TH1F ();
    TH1F * Higgs = nuevo  TH1F ();
    TH1F * Z_tautau = nuevo  TH1F ();
    TH1F * stop_tq = nuevo  TH1F ();
    TH1F * stop_tWtb = nuevo  TH1F ();
    TH1F * ZVV = nuevo  TH1F ();
    TH1F * ZPrime = nuevo  TH1F ();
    
    // fusión para análisis WBoson y SingleTop y ZPrimeBoosted
    if (opción. encontrar ( " WBosonAnalysis " )! = opción. npos ||
        opción. find ( " SingleTopAnalysis " )! = opción. npos ||
	opción. find ( " ZPrimeBoostedAnalysis " )! = opción. npos )
    {
      
      // muestras de diboson
      diboson = (TH1F *) WlvZqq [ después -> primero ] -> Clon ();
      diboson-> Add (WplvWmqq [ fIter -> first ]);
      if (! (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos )) diboson-> Add (WpqqWmlv [ fIter -> first ]);
      diboson-> Add (ZqqZll [ fIter -> first ]);
      diboson-> Add (WqqZll [ fIter -> first ]);
      if (! (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos )) diboson-> Add ( llll [ fIter -> first ]);
      diboson-> Add (lllv [ fIter -> first ]);
      diboson-> Add (llvv [ fIter -> first ]);
      diboson-> Add (lvvv [ fIter -> first ]);
      diboson-> SetFillColor ( kBlue - 6 );
      diboson-> SetLineWidth ( 0 );
  
      // muestras en rodajas de W + jets
      W = (TH1F *) Wenu_PTV0_70_BFilter [ fIter -> first ] -> Clone ();
      W-> Agregar (Wenu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wenu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV70_140_CFilterBVeto [ fIter -> primero ]);
      W-> Agregar (Wenu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> SetFillColor ( kGreen - 3 );
      W-> SetLineWidth ( 0 );
      if (opción. encontrar ( " SingleTopAnalysis " )! = opción. npos ) W-> Scale ( 1.1 ); // cambia a mano la normalización de la región de validación
      

      // muestras Z inclusivas (también podría usar muestras en rodajas, sin embargo, esto acelera el proceso ya que se trata de un trasfondo menor)     
      Z = (TH1F *) Zmumu [ después -> primero ] -> Clonar ();
      Z-> Agregar (Ztautau [ después -> primero ]);
      Z-> Add (Zee [ fIter -> first ]);
      Z-> SetFillColor ( kPink + 9 );
      Z-> SetLineWidth ( 0 );
    
      V = (TH1F *) W-> Clon ();
      V-> Agregar (Ztautau [ después -> primero ]);
      V-> Add (Zee [ fIter -> first ]);
      V-> Agregar (Zmumu [ fIter -> first ]);
      V-> SetFillColor ( kGreen - 3 );
      V-> SetLineWidth ( 0 );

      if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {
        ZPrime = (TH1F *) ZPrime1000 [ fIter -> first ] -> Clone ();
        ZPrime-> SetFillColor ( kRed );
        ZPrime-> SetLineWidth ( 0 );
      }

      ttbar = (TH1F *) ttbar_lep [ fIter -> first ] -> Clone ();
      ttbar-> SetFillColor ( kOrange - 3 );
      ttbar-> SetLineWidth ( 0 );
      if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {
	      if (! ( fIter -> first . find ( " leadLR " )! = option. npos )) ttbar-> Scale ( 0.91 ); // cambiar a mano la normalización en función de los jets R grandes
      }

      detener = (TH1F *) single_top_tchan [ fIter -> first ] -> Clone ();
      detener-> Agregar (single_antitop_tchan [ fIter -> first ]);
      detener-> Agregar (single_top_wtchan [ fIter -> first ]);
      detener-> Agregar (single_antitop_wtchan [ fIter -> first ]);
      detener-> Agregar (single_top_schan [ fIter -> first ]);
      detener-> Agregar (single_antitop_schan [ fIter -> first ]);
detener-       > SetFillColor ( kAzure + 8 );
detener-       > SetLineWidth ( 0 );

      // solo top sencillo de canal en T
      stop_tq = (TH1F *) single_top_tchan [ fIter -> first ] -> Clone ();
      stop_tq-> Add (single_antitop_tchan [ fIter -> first ]);
      stop_tq-> SetFillColor ( kAzure + 8 );
      stop_tq-> SetLineWidth ( 0 );

      // otro single top (tW, s-channel) y ttbar
      stop_tWtb = (TH1F *) single_top_wtchan [ fIter -> first ] -> Clone ();
      stop_tWtb-> Add (single_antitop_wtchan [ fIter -> first ]);
      stop_tWtb-> Add (single_top_schan [ fIter -> first ]);
      stop_tWtb-> Add (single_antitop_schan [ fIter -> first ]);
      stop_tWtb-> Add (ttbar_lep [ fIter -> first ]);
      stop_tWtb-> SetFillColor ( kOrange - 3 );
      stop_tWtb-> SetLineWidth ( 0 );

      // especial Z y diboson
      ZVV = (TH1F *) Zmumu [ fIter -> first ] -> Clone ();
      ZVV-> Agregar (Ztautau [ después -> primero ]);
      ZVV-> Agregar (Zee [ después -> primero ]);
      ZVV-> Add (WlvZqq [ fIter -> first ]);
      ZVV-> Agregar (WplvWmqq [ fIter -> first ]);
      if (! (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos )) ZVV-> Add (WpqqWmlv [ fIter -> first ]);
      ZVV-> Agregar (ZqqZll [ fIter -> first ]);
      ZVV-> Agregar (WqqZll [ fIter -> first ]);
      if (! (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos )) ZVV-> Add ( llll [ fIter -> first ]);
      ZVV-> Add (lllv [ fIter -> first ]);
      ZVV-> Add (llvv [ fIter -> first ]);
      ZVV-> Add (lvvv [ fIter -> first ]);
      ZVV-> SetFillColor ( kPink + 9 );
      ZVV-> SetLineWidth ( 0 );


    }
    
    // fusionar para Top
    if (option. find ( " TTbarAnalysis " )! = option. npos || option. find ( " ZBosonAnalysis " )! = option. npos || option. find ( " WZDiBosonAnalysis " )! = option. npos || option. find ( " ZZDiBosonAnalysis " )! = Opción. Npos ) {

      // ttbar
      ttbar = (TH1F *) ttbar_lep [ fIter -> first ] -> Clone ();
      ttbar-> SetFillColor ( kOrange - 3 );
      ttbar-> SetLineWidth ( 0 );

      // todo diboson
      diboson = (TH1F *) WlvZqq [ después -> primero ] -> Clon ();
      diboson-> Add (WplvWmqq [ fIter -> first ]);
      diboson-> Add (WpqqWmlv [ fIter -> first ]);
      diboson-> Add (ZqqZll [ fIter -> first ]);
      diboson-> Add (WqqZll [ fIter -> first ]);
      diboson-> Add ( llll [ fIter -> first ]);
      diboson-> Add (lllv [ fIter -> first ]);
      diboson-> Add (llvv [ fIter -> first ]);
      diboson-> Add (lvvv [ fIter -> first ]);
      diboson-> SetFillColor ( kBlue - 6 );
      diboson-> SetLineWidth ( 0 );

      // dividir diboson en WW + ZZ
      VV = (TH1F *) WplvWmqq [ después -> primero ] -> Clonar (); // WW
      VV-> Agregar (WpqqWmlv [ fIter -> first ]); // WW
      VV-> Agregar (ZqqZll [ fIter -> first ]); // Z-> qq Z-> ll
      VV-> Add ( llll [ fIter -> first ]); // Z-> ll Z-> ll
      VV-> Add (llvv [ fIter -> first ]); // Z-> ll Z-> vv
      VV-> SetFillColor ( kBlue - 6 );
      VV-> SetLineWidth ( 0 );
      
      // solo WZ
      W_Z = (TH1F *) lllv [ fIter -> first ] -> Clone (); // W-> lv Z-> ll
      W_Z-> Add (lvvv [ fIter -> first ]); // W-> lv Z-> vv
      W_Z-> Agregar (WqqZll [ fIter -> first ]); // W-> qq Z-> ll
      W_Z-> Add (WlvZqq [ fIter -> first ]);  // W-> lv Z-> qq
      W_Z-> SetFillColor ( kRed - 7 );
      W_Z-> SetLineWidth ( 0 );


      // dividir diboson en WW + WZ
      WWZ = (TH1F *) WplvWmqq [ fIter -> first ] -> Clone (); // WW
      WWZ-> Agregar (WpqqWmlv [ fIter -> first ]); // WW
      WWZ-> Add (lllv [ fIter -> first ]);  // // W-> lv Z-> ll
      WWZ-> Add (lvvv [ fIter -> first ]); // W-> lv Z-> vv
      WWZ-> Agregar (WqqZll [ fIter -> first ]); // W-> qq Z-> ll
      WWZ-> Agregar (WlvZqq [ fIter -> first ]);  // W-> lv Z-> qq
      WWZ-> SetFillColor ( kRed - 7 );
      WWZ-> SetLineWidth ( 0 );

      // solo ZZ
      Z_Z = (TH1F *) llll [ fIter -> first ] -> Clone (); // Z-> ll Z-> ll
      Z_Z-> Add (ZqqZll [ fIter -> first ]); // Z-> qq Z-> ll
      Z_Z-> Add (llvv [ fIter -> first ]); // Z-> ll Z-> vv
      Z_Z-> SetFillColor ( kBlue - 6 );
      Z_Z-> SetLineWidth ( 0 );
      //       Z_Z-> Escala (1.08); // gluón-gluón inducido por bucle gg-> ZZ no está incluido en los MC actuales, que se pueden ver en la región de control de 4 leptones


      // parte superior simple
      detener = (TH1F *) single_top_tchan [ fIter -> first ] -> Clone ();
      detener-> Agregar (single_antitop_tchan [ fIter -> first ]);
      detener-> Agregar (single_top_wtchan [ fIter -> first ]);
      detener-> Agregar (single_antitop_wtchan [ fIter -> first ]);
      detener-> Agregar (single_top_schan [ fIter -> first ]);
      detener-> Agregar (single_antitop_schan [ fIter -> first ]);
detener-       > SetFillColor ( kAzure + 8 );
detener-       > SetLineWidth ( 0 );

      // agrega ttbar y single top
      arriba = (TH1F *) ttbar-> Clonar ();
      arriba-> Agregar (detener);
      arriba-> SetFillColor ( kOrange - 3 );
      arriba-> SetLineWidth ( 0 );

      // Chorros V +, tanto W como Z
      V = (TH1F *) Wplusenu [ fIter -> first ] -> Clone ();
      V-> Agregar (Wplusmunu [ fIter -> first ]);
      V-> Agregar (Wplustaunu [ fIter -> first ]);
      V-> Agregar (Wminusenu [ fIter -> first ]);
      V-> Agregar (Wminusmunu [ fIter -> first ]);
      V-> Agregar (Wminustaunu [ fIter -> first ]);
      V-> Agregar (Ztautau [ después -> primero ]);
      V-> Add (Zee [ fIter -> first ]);
      V-> Agregar (Zmumu [ fIter -> first ]);
      V-> SetFillColor ( kGreen - 3 );
      V-> SetLineWidth ( 0 );
    
      
      // ttbar, top simple, chorros V +
      topV = (TH1F *) top-> Clonar ();
      topV-> Agregar (V);
      topV-> SetFillColor ( kGreen - 3 );
      topV-> SetLineWidth ( 0 );

 
 
      Z = (TH1F *) Zmumu [ después -> primero ] -> Clonar ();
      Z-> Agregar (Ztautau [ después -> primero ]);
      Z-> Add (Zee [ fIter -> first ]);
      Z-> SetFillColor ( kPink + 9 );
      Z-> SetLineWidth ( 0 );

      W = (TH1F *) Wplusenu [ fIter -> first ] -> Clone ();
      W-> Agregar (Wplusmunu [ fIter -> first ]);
      W-> Agregar (Wplustaunu [ fIter -> first ]);
      W-> Agregar (Wminusenu [ fIter -> first ]);
      W-> Agregar (Wminusmunu [ fIter -> first ]);
      W-> Agregar (Wminustaunu [ fIter -> first ]);
      W-> SetFillColor ( kGreen - 3 );
      W-> SetLineWidth ( 0 );

    }

    // fusionar para HWW _Analysis
    if (option. find ( " HWWAnalysis " )! = option. npos ) {
      
      Higgs = (TH1F *) ggH125_WW2lep [ fIter -> first ] -> Clone ();
      Higgs-> Add (VBFH125_WW2lep [ fIter -> first ]);
      Higgs-> SetFillColor ( kRed );
      Higgs-> SetLineWidth ( 0 );

      ttbar = (TH1F *) ttbar_lep [ fIter -> first ] -> Clone ();
      ttbar-> SetFillColor ( kOrange - 3 );
      ttbar-> SetLineWidth ( 0 );

      diboson = (TH1F *) WlvZqq [ después -> primero ] -> Clon ();
      diboson-> Add (WplvWmqq [ fIter -> first ]);
      diboson-> Add (WpqqWmlv [ fIter -> first ]);
      diboson-> Add (ZqqZll [ fIter -> first ]);
      diboson-> Add (WqqZll [ fIter -> first ]);
      diboson-> Add ( llll [ fIter -> first ]);
      diboson-> Add (lllv [ fIter -> first ]);
      diboson-> Add (llvv [ fIter -> first ]);
      diboson-> Add (lvvv [ fIter -> first ]);
      diboson-> SetFillColor ( kBlue - 6 );
      diboson-> SetLineWidth ( 0 );
      dibosón-> Escala ( 1.3 ); // escala de normalización, de la región de control de WW necesitamos un factor de 1.3, la subestimación de la sección transversal de WZ requiere un factor de normalización de 1.15-1.2, además las contribuciones con leptones mal identificados no se estiman ni agregan => se toma un total de 1.3

      V = (TH1F *) Wplusenu [ fIter -> first ] -> Clone ();
      V-> Agregar (Wplusmunu [ fIter -> first ]);
      V-> Agregar (Wplustaunu [ fIter -> first ]);
      V-> Agregar (Wminusenu [ fIter -> first ]);
      V-> Agregar (Wminusmunu [ fIter -> first ]);
      V-> Agregar (Wminustaunu [ fIter -> first ]);
      V-> Agregar (Ztautau [ después -> primero ]);
      V-> Add (Zee [ fIter -> first ]);
      V-> Agregar (Zmumu [ fIter -> first ]);
      V-> SetFillColor ( kGreen - 3 );
      V-> SetLineWidth ( 0 );

      detener = (TH1F *) single_top_tchan [ fIter -> first ] -> Clone ();
      detener-> Agregar (single_antitop_tchan [ fIter -> first ]);
      detener-> Agregar (single_top_wtchan [ fIter -> first ]);
      detener-> Agregar (single_antitop_wtchan [ fIter -> first ]);
      detener-> Agregar (single_top_schan [ fIter -> first ]);
      detener-> Agregar (single_antitop_schan [ fIter -> first ]);
detener-       > SetFillColor ( kAzure + 8 );
detener-       > SetLineWidth ( 0 );

    }

    // fusionar para SUSYAnalysis
    if (option. find ( " SUSYAnalysis " )! = option. npos ) {
      
      diboson = (TH1F *) WlvZqq [ después -> primero ] -> Clon ();
      diboson-> Add (WplvWmqq [ fIter -> first ]);
      diboson-> Add (WpqqWmlv [ fIter -> first ]);
      diboson-> Add (ZqqZll [ fIter -> first ]);
      diboson-> Add (WqqZll [ fIter -> first ]);
      diboson-> Add ( llll [ fIter -> first ]);
      diboson-> Add (lllv [ fIter -> first ]);
      diboson-> Add (llvv [ fIter -> first ]);
      diboson-> Add (lvvv [ fIter -> first ]);
      diboson-> SetFillColor ( kBlue - 6 );
      diboson-> SetLineWidth ( 0 );
 
      // muestras en rodajas de W + jets
      W = (TH1F *) Wenu_PTV0_70_BFilter [ fIter -> first ] -> Clone ();
      W-> Agregar (Wenu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wenu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV70_140_CFilterBVeto [ fIter -> primero ]);
      W-> Agregar (Wenu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> SetFillColor ( kGreen - 3 );
      W-> SetLineWidth ( 0 );
 
      Z = (TH1F *) Zee_PTV0_70_BFilter [ fIter -> first ] -> Clone ();
      Z-> Agregar (Zee_PTV0_70_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV0_70_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV1000 [ fIter -> first ]);
      Z-> Agregar (Zee_PTV140_280_BFilter [ fIter -> first ]);
      Z-> Agregar (Zee_PTV140_280_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV140_280_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV280_500_BFilter [ fIter -> first ]);
      Z-> Agregar (Zee_PTV280_500_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV280_500_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV500_1000 [ fIter -> first ]);
      Z-> Agregar (Zee_PTV70_140_BFilter [ fIter -> first ]);
      Z-> Agregar (Zee_PTV70_140_CFilterBVeto [ fIter -> primero ]);
      Z-> Agregar (Zee_PTV70_140_CVetoBVeto [ fIter -> first ]);
      
      Z-> Agregar (Zmumu_PTV0_70_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      Z-> Add (Zmumu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV1000 [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV140_280_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV280_500_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV500_1000 [ después -> primero ]);
      Z-> Agregar (Zmumu_PTV70_140_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      
      Z-> Agregar (Ztautau_PTV0_70_BFilter [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV0_70_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV0_70_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV1000 [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV140_280_BFilter [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV140_280_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV140_280_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV280_500_BFilter [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV280_500_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV280_500_CVetoBVeto [ fIter -> first ]);
      Z-> Add (Ztautau_PTV500_1000 [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV70_140_BFilter [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV70_140_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Ztautau_PTV70_140_CVetoBVeto [ fIter -> first ]);
      Z-> SetFillColor ( kPink + 9 );
      Z-> SetLineWidth ( 0 );
      
      ttbar = (TH1F *) ttbar_lep [ fIter -> first ] -> Clone ();
      ttbar-> SetFillColor ( kOrange - 3 );
      ttbar-> SetLineWidth ( 0 );
      
      detener = (TH1F *) single_top_tchan [ fIter -> first ] -> Clone ();
      detener-> Agregar (single_antitop_tchan [ fIter -> first ]);
      detener-> Agregar (single_top_wtchan [ fIter -> first ]);
      detener-> Agregar (single_antitop_wtchan [ fIter -> first ]);
      detener-> Agregar (single_top_schan [ fIter -> first ]);
      detener-> Agregar (single_antitop_schan [ fIter -> first ]);
detener-       > SetFillColor ( kAzure + 8 );
detener-       > SetLineWidth ( 0 );

    }

    // fusionando para HZZ
    if (option. find ( " HZZAnalysis " )! = option. npos ) {

      // fusiona todos los bkgs menores
      V = (TH1F *) Wplusenu [ fIter -> first ] -> Clone ();
      V-> Agregar (Wplusmunu [ fIter -> first ]);
      V-> Agregar (Wplustaunu [ fIter -> first ]);
      V-> Agregar (Wminusenu [ fIter -> first ]);
      V-> Agregar (Wminusmunu [ fIter -> first ]);
      V-> Agregar (Wminustaunu [ fIter -> first ]);
      V-> Agregar (Ztautau [ después -> primero ]);
      V-> Add (Zee [ fIter -> first ]);
      V-> Agregar (Zmumu [ fIter -> first ]);
      V-> Agregar (single_top_schan [ fIter -> first ]);
      V-> Agregar (single_antitop_schan [ fIter -> first ]);
      V-> Agregar (single_top_tchan [ fIter -> first ]);
      V-> Agregar (single_antitop_tchan [ fIter -> first ]);
      V-> Agregar (single_top_wtchan [ fIter -> first ]);
      V-> Agregar (single_antitop_wtchan [ fIter -> first ]);
      V-> Agregar (ttbar_lep [ fIter -> first ]);
      V-> Agregar (WplvWmqq [ fIter -> first ]); // WW
      V-> Agregar (WpqqWmlv [ fIter -> first ]); // WW
      V-> Add (lllv [ fIter -> first ]);  // // W-> lv Z-> ll
      V-> Add (lvvv [ fIter -> first ]); // W-> lv Z-> vv
      V-> Agregar (WqqZll [ fIter -> first ]); // W-> qq Z-> ll
      V-> Agregar (WlvZqq [ fIter -> first ]);  // W-> lv Z-> qq
      V-> SetFillColor ( kBlue - 6 );
      V-> SetLineWidth ( 0 );

      // solo ZZ
      Z_Z = (TH1F *) llll [ fIter -> first ] -> Clone (); // Z-> ll Z-> ll
      Z_Z-> Add (ZqqZll [ fIter -> first ]); // Z-> qq Z-> ll
      Z_Z-> Add (llvv [ fIter -> first ]); // Z-> ll Z-> vv
      Z_Z-> SetFillColor ( kAzure + 8 );
      Z_Z-> SetLineWidth ( 0 );
      Z_Z-> Escala ( 1.3 ); // gluón-gluón inducido por bucle gg-> ZZ no está incluido en los MC actuales

      Higgs = (TH1F *) ggH125_ZZ4lep [ fIter -> first ] -> Clone ();
      Higgs-> Agregar (ZH125_ZZ4lep [ fIter -> first ]);
      Higgs-> Add (WH125_ZZ4lep [ fIter -> first ]);
      Higgs-> Add (VBFH125_ZZ4lep [ fIter -> first ]);
      Higgs-> SetFillColor ( kRed );
      Higgs-> SetLineWidth ( 0 );

    }

    // fusionar para ZTauTauAnalysis
    if (option. find ( " ZTauTauAnalysis " )! = option. npos ) {

      // ttbar
      ttbar = (TH1F *) ttbar_lep [ fIter -> first ] -> Clone ();
      ttbar-> SetFillColor ( kOrange - 3 );
      ttbar-> SetLineWidth ( 0 );

      // todo diboson
      diboson = (TH1F *) WlvZqq [ después -> primero ] -> Clon ();
      diboson-> Add (WplvWmqq [ fIter -> first ]);
      diboson-> Add (WpqqWmlv [ fIter -> first ]);
      diboson-> Add (ZqqZll [ fIter -> first ]);
      diboson-> Add (WqqZll [ fIter -> first ]);
      diboson-> Add ( llll [ fIter -> first ]);
      diboson-> Add (lllv [ fIter -> first ]);
      diboson-> Add (llvv [ fIter -> first ]);
      diboson-> Add (lvvv [ fIter -> first ]);
      diboson-> SetFillColor ( kBlue - 6 );
      diboson-> SetLineWidth ( 0 );

      // parte superior simple
      detener = (TH1F *) single_top_tchan [ fIter -> first ] -> Clone ();
      detener-> Agregar (single_antitop_tchan [ fIter -> first ]);
      detener-> Agregar (single_top_wtchan [ fIter -> first ]);
      detener-> Agregar (single_antitop_wtchan [ fIter -> first ]);
      detener-> Agregar (single_top_schan [ fIter -> first ]);
      detener-> Agregar (single_antitop_schan [ fIter -> first ]);
detener-       > SetFillColor ( kAzure + 8 );
detener-       > SetLineWidth ( 0 );

      // fusionar bkgs menores
      topV = (TH1F *) ttbar-> Clonar ();
      topV-> Agregar (detener);
      topV-> Agregar (diboson);
      topV-> SetFillColor ( kOrange - 3 );
      topV-> SetLineWidth ( 0 );

      // muestras de chorros Sherpa W + en rodajas
      W = (TH1F *) Wenu_PTV0_70_BFilter [ fIter -> first ] -> Clone ();
      W-> Agregar (Wenu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wenu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wenu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wenu_PTV70_140_CFilterBVeto [ fIter -> primero ]);
      W-> Agregar (Wenu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wmunu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV1000 [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV500_1000 [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_BFilter [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      W-> Agregar (Wtaunu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      W-> SetFillColor ( kGreen - 3 );
      W-> SetLineWidth ( 0 );

      // muestras de jets Sherpa Z + en rodajas
      // fusionar Z-> ee y Z-> mumu
      Z = (TH1F *) Zee_PTV0_70_BFilter [ fIter -> first ] -> Clone ();
      Z-> Agregar (Zee_PTV0_70_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV0_70_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV1000 [ fIter -> first ]);
      Z-> Agregar (Zee_PTV140_280_BFilter [ fIter -> first ]);
      Z-> Agregar (Zee_PTV140_280_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV140_280_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV280_500_BFilter [ fIter -> first ]);
      Z-> Agregar (Zee_PTV280_500_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV280_500_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zee_PTV500_1000 [ fIter -> first ]);
      Z-> Agregar (Zee_PTV70_140_BFilter [ fIter -> first ]);
      Z-> Agregar (Zee_PTV70_140_CFilterBVeto [ fIter -> primero ]);
      Z-> Agregar (Zee_PTV70_140_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV0_70_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV0_70_CFilterBVeto [ fIter -> first ]);
      Z-> Add (Zmumu_PTV0_70_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV1000 [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV140_280_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV140_280_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV140_280_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV280_500_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV280_500_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV280_500_CVetoBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV500_1000 [ después -> primero ]);
      Z-> Agregar (Zmumu_PTV70_140_BFilter [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV70_140_CFilterBVeto [ fIter -> first ]);
      Z-> Agregar (Zmumu_PTV70_140_CVetoBVeto [ fIter -> first ]);
      Z-> SetFillColor ( kPink + 9 );
      Z-> SetLineWidth ( 0 );

      // Z-> tau tau      
      Z_tautau = (TH1F *) Ztautau_PTV0_70_BFilter [ fIter -> first ] -> Clone ();
      Z_tautau-> Add (Ztautau_PTV0_70_CFilterBVeto [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV0_70_CVetoBVeto [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV1000 [ fIter -> first ]);
      Z_tautau-> Agregar (Ztautau_PTV140_280_BFilter [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV140_280_CFilterBVeto [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV140_280_CVetoBVeto [ fIter -> first ]);
      Z_tautau-> Agregar (Ztautau_PTV280_500_BFilter [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV280_500_CFilterBVeto [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV280_500_CVetoBVeto [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV500_1000 [ fIter -> first ]);
      Z_tautau-> Agregar (Ztautau_PTV70_140_BFilter [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV70_140_CFilterBVeto [ fIter -> first ]);
      Z_tautau-> Add (Ztautau_PTV70_140_CVetoBVeto [ fIter -> first ]);
      Z_tautau-> SetFillColor ( kAzure + 7 );
      Z_tautau-> SetLineWidth ( 0 );
     
     }

    // fusionar para HyyAnalysis
    if (option. find ( " HyyAnalysis " )! = option. npos ) {
      Higgs = (TH1F *) ggH125_gamgam [ fIter -> first ] -> Clone ();
      Higgs-> Agregar (ttH125_gamgam [ fIter -> first ]);
      Higgs-> Add (VBFH125_gamgam [ fIter -> first ]);
      Higgs-> Add (WH125_gamgam [ fIter -> first ]);
      Higgs-> Add (ZH125_gamgam [ fIter -> first ]);
      Higgs-> SetLineColor ( kBlack );
      Higgs-> SetLineWidth ( 2 );
    }

    
    // ////////////////////////////////////////////////// ////////////////////////////////////////////////
    
    // pila principal de MC
    THStack * pila = nuevo  THStack ();
   
    // histograma de error estadístico
    TH1F * histstack = nuevo  TH1F ();
      
    // El orden de la pila define qué muestras aparecerán una encima de la otra
    if (option. find ( " WBosonAnalysis " )! = option. npos ) {
      apilar-> Agregar (detener);
      pila-> Agregar (ttbar);
      pila-> Agregar (diboson);
      pila-> Agregar (Z);
      pila-> Agregar (W);
    
      histstack = (TH1F *) ttbar-> Clonar ();
      histstack-> Agregar (Z);
      histstack-> Agregar (diboson);
      histstack-> Agregar (W);
      histstack-> Agregar (detener);
    }
    
    if (option. find ( " TTbarAnalysis " )! = option. npos || option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {
      pila-> Agregar (diboson);
      apilar-> Agregar (detener);
      pila-> Agregar (V);
      pila-> Agregar (ttbar);

      histstack = (TH1F *) ttbar-> Clonar ();
      histstack-> Agregar (detener);
      histstack-> Agregar (diboson);
      histstack-> Agregar (V);
    }
    
    if (option. find ( " SingleTopAnalysis " )! = option. npos ) {
      pila-> Agregar (ZVV);
      pila-> Agregar (W);
      pila-> Agregar (stop_tWtb);
      pila-> Agregar (stop_tq);
      
      histstack = (TH1F *) ZVV-> Clon ();
      histstack-> Agregar (W);
      histstack-> Agregar (stop_tq);
      histstack-> Agregar (stop_tWtb);
    }
   
    if (option. find ( " ZBosonAnalysis " )! = option. npos ) {
      pila-> Agregar (W);
      apilar-> Agregar (detener);
      pila-> Agregar (ttbar);
      pila-> Agregar (diboson);
      pila-> Agregar (Z);

      histstack = (TH1F *) ttbar-> Clonar ();
      histstack-> Agregar (Z);
      histstack-> Agregar (diboson);
      histstack-> Agregar (W);
      histstack-> Agregar (detener);
    }

    if (option. find ( " WZDiBosonAnalysis " )! = option. npos ) {
      pila-> Agregar (arriba);
      pila-> Agregar (V);
      pila-> Agregar (VV);
      pila-> Agregar (W_Z);

      histstack = (TH1F *) arriba-> Clonar ();
      histstack-> Agregar (V);
      histstack-> Agregar (VV);
      histstack-> Agregar (W_Z);
    }

    if (option. find ( " ZZDiBosonAnalysis " )! = option. npos ) {
      pila-> Agregar (topV);
      pila-> Agregar (WWZ);
      pila-> Agregar (Z_Z);

      histstack = (TH1F *) topV-> Clon ();
      histstack-> Agregar (WWZ);
      histstack-> Agregar (Z_Z);
    }
  
    if (option. find ( " HZZAnalysis " )! = option. npos ) {
      pila-> Agregar (V);
      pila-> Agregar (Z_Z);
      pila-> Agregar (Higgs);

      histstack = (TH1F *) V-> Clon ();
      histstack-> Agregar (Higgs);
      histstack-> Agregar (Z_Z);
    }
    
    if (option. find ( " HWWAnalysis " )! = option. npos ) {
      apilar-> Agregar (detener);
      pila-> Agregar (ttbar);
      pila-> Agregar (V);
      pila-> Agregar (diboson);
      pila-> Agregar (Higgs);

      histstack = (TH1F *) ttbar-> Clonar ();
      histstack-> Agregar (diboson);
      histstack-> Agregar (V);
      histstack-> Agregar (detener);
      histstack-> Agregar (Higgs);
    }

    if (option. find ( " ZTauTauAnalysis " )! = option. npos ) {
      pila-> Agregar (topV);
      pila-> Agregar (W);
      pila-> Agregar (Z);
      pila-> Agregar (Z_tautau);

      histstack = (TH1F *) topV-> Clon ();
      histstack-> Agregar (W);
      histstack-> Agregar (Z);
      histstack-> Agregar (Z_tautau);
    }

   if (option. find ( " SUSYAnalysis " )! = option. npos ) {
      pila-> Agregar (W);
      apilar-> Agregar (detener);
      pila-> Agregar (ttbar);
      pila-> Agregar (diboson);
      pila-> Agregar (Z);

      histstack = (TH1F *) ttbar-> Clonar ();
      histstack-> Agregar (Z);
      histstack-> Agregar (diboson);
      histstack-> Agregar (W);
      histstack-> Agregar (detener);
    }
    
    if (option. find ( " HyyAnalysis " )! = option. npos ) {
      pila-> Agregar (Higgs);
      histstack = (TH1F *) Higgs-> Clon ();
    }

    // desbordamiento de datos
    if ( std :: strstr (( después -> primero ). c_str (), " cuatro_lep " ) == NULL ) {
    if ( abs ( después -> segundo -> GetBinContent ( después -> segundo -> GetNbinsX () + 1 ))> 0 ) {
     fIter -> segundo -> AddBinContent ( fIter -> segundo -> GetNbinsX (), fIter -> segundo -> GetBinContent ( fIter -> segundo -> GetNbinsX () + 1 ));
    }
    }
    // ////////////////////////////////////////////////// /////////////////////////////
    // COMENZAR EL TRAZADO //


    histstack-> SetFillStyle ( 3454 );
    histstack-> SetFillColor ( kBlue + 2 );
    histstack-> SetLineColor ( kBlack );
    histstack-> SetLineWidth ( 2 );
    histstack-> SetMarkerSize ( 0 );
    histstack-> SetLineColor ( kWhite );
    
    // obtener la incertidumbre estadística
    flotar err;
    int nbin = histstack-> GetNbinsX ();
    para ( int i_bin = 0 ; i_bin <= nbin; i_bin ++) {
      err = histstack-> GetBinError (i_bin);
      histstack-> SetBinError (i_bin, err);
    }
    
    // calcular señales normalizadas
    TH1F * Higgs_normsig = nuevo  TH1F ();
    if (option. find ( " HZZAnalysis " )! = option. npos ) {
      Higgs_normsig = (TH1F *) ggH125_ZZ4lep [ fIter -> first ] -> Clone ();
      Higgs_normsig-> Add (ZH125_ZZ4lep [ fIter -> first ]);
      Higgs_normsig-> Add (WH125_ZZ4lep [ fIter -> first ]);
      Higgs_normsig-> Add (VBFH125_ZZ4lep [ fIter -> first ]);
      Higgs_normsig-> Escala (histstack-> Integral () / Higgs_normsig-> Integral ());
      Higgs_normsig-> SetLineColor ( kRed );
      Higgs_normsig-> SetFillStyle ( 0 );
      Higgs_normsig-> SetLineStyle ( 2 );
      Higgs_normsig-> SetFillColor ( 2 );
      Higgs_normsig-> SetLineWidth ( 2 );
    }
  
    if (option. find ( " HWWAnalysis " )! = option. npos ) {
      Higgs_normsig = (TH1F *) Higgs-> Clon ();
      Higgs_normsig-> Escala (histstack-> Integral () / Higgs_normsig-> Integral ());
      Higgs_normsig-> SetLineColor ( kRed );
      Higgs_normsig-> SetFillStyle ( 0 );
      Higgs_normsig-> SetLineStyle ( 2 );
      Higgs_normsig-> SetFillColor ( 2 );
      Higgs_normsig-> SetLineWidth ( 2 );
    }

    TH1F * stop_normsig = nuevo  TH1F ();
    if (option. find ( " SingleTopAnalysis " )! = option. npos ) {
      stop_normsig = (TH1F *) stop_tq-> Clonar ();
      stop_normsig-> Scale (histstack-> Integral () / stop_normsig-> Integral ());
      stop_normsig-> SetLineColor ( kRed );
      stop_normsig-> SetFillStyle ( 0 );
      stop_normsig-> SetLineStyle ( 2 );
      stop_normsig-> SetFillColor ( 2 );
      stop_normsig-> SetLineWidth ( 2 );
    }

    TH1F * ZPrime_normsig = nuevo  TH1F ();
    if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {
      ZPrime_normsig = (TH1F *) ZPrime-> Clonar ();
      ZPrime_normsig -> Escala (histstack-> Integral () / ZPrime_normsig-> Integral ());
      ZPrime_normsig-> SetLineColor ( kRed );
      ZPrime_normsig-> SetFillStyle ( 0 );
      ZPrime_normsig-> SetLineStyle ( 2 );
      ZPrime_normsig-> SetFillColor ( 2 );
      ZPrime_normsig-> SetLineWidth ( 2 );
    }

    
    TH1F * slep600DM300_normsig = nuevo  TH1F ();
    if (option. find ( " SUSYAnalysis " )! = option. npos ) {
      slep600DM300_normsig = (TH1F *) slep600DM300 [ fIter -> first ] -> Clone ();
      slep600DM300_normsig-> SetLineColor ( kRed );
      slep600DM300_normsig-> SetFillStyle ( 0 );
      slep600DM300_normsig-> SetLineStyle ( 2 );
      slep600DM300_normsig-> SetFillColor ( 2 );
      slep600DM300_normsig-> SetLineWidth ( 2 );
    }


    // establecer el máximo de Yaxis
    flotar yMaxScale = 2 .;
    fIter -> segundo -> SetMaximum (yMaxScale * TMath :: Max ( TMath :: Max ( fIter -> segundo -> GetMaximum (), histstack-> GetMaximum ()), Higgs_normsig-> GetMaximum ()));
    
    
    // opciones de látex
    TLatex l;
    l. SetNDC ();
    l. SetTextColor ( kBlack );
    l. SetTextFont ( 42 );
    l. SetTextSize ( 0.04 );
    
    if (option. find ( " WBosonAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " W #rightarrow l # nu " );}
    if (option. find ( " TTbarAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " t # bar {t} #rightarrow l # nub q # bar {q} b " );}
    if (option. find ( " SingleTopAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " t #rightarrow l # nub + q " );}
    if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " Z '#rightarrow t # bar {t} (aumentado) " );}
    if (option. find ( " ZBosonAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " Z #rightarrow l ^ {+} l ^ {-} " );}
    if (option. find ( " HWWAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " H #rightarrow WW * #rightarrow e # nu # mu # nu, N_ {jet} #leq 1 " );}
    if (option. find ( " WZDiBosonAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " WZ #rightarrow l # nu ll " );}
    if (option. find ( " ZZDiBosonAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " ZZ #rightarrow l ^ {+} l ^ {-} l ^ {+} l ^ {-} " );}
    if (option. find ( " HZZAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " H #rightarrow ZZ * #rightarrow 4l " );}
    if (option. find ( " ZTauTauAnalysis " )! = option. npos ) {l. DrawLatex ( 0.18 , 0.71 , " Z #rightarrow #tau_ {l} #tau_ {h} " );}

    if (option. find ( " SUSYAnalysis " )! = option. npos ) {
        if ( después -> primero . encontrar ( " SR_loose " )! = opción. npos ) l. DrawLatex ( 0,18 , 0,71 , " 2l + 0 chorros, SR suelto " );
	otra cosa  si ( FITER -> primero . encontrar ( " SR_tight " ) = opción!. npos ) l. DrawLatex ( 0,18 , 0,71 , " 2l + 0 chorros, SR apretado " );
	más l. DrawLatex ( 0,18 , 0,71 , " 2l + 0 chorros " );
    }

    if (option. find ( " HyyAnalysis " )! = option. npos ) {
        if ( después -> primero . buscar ( " _cat_ " )! = opción. npos ) l. DrawLatex ( 0.18 , 0.71 , " H #rightarrow #gamma #gamma, inconv. Central " );
        más l. DrawLatex ( 0.18 , 0.71 , " H #rightarrow #gamma #gamma " );
    }

    TLatex l2;
    l2. SetNDC ();
    l2. SetTextSize ( 0.04 );  
    l2. SetTextColor ( kBlack );
    l2. DrawLatex ( 0.18 , 0.79 , Form ( " #sqrt {s} = 13 TeV, 10 fb ^ {- 1} " ));
    
    
    // crear leyenda
    TLegend * leg;
    pierna = nueva  TLegend ();
    leg = new  TLegend ( 0,70 , 0,50 , 0,93 , 0,925 );
    if (option. find ( " HyyAnalysis " )! = option. npos ) leg = new  TLegend ( 0.60 , 0.45 , 0.93 , 0.825 );
pierna-     > SetFillStyle ( 0 );
pierna-     > SetBorderSize ( 0 );
pierna-     > SetTextAlign ( 32 );
pierna-     > SetTextFont ( 42 );
pierna-     > SetTextSize ( 0.05 );
pierna-     > SetMargin ( 0.22 );
pierna-     > SetTextAlign ( 32 );
    
    // completar la leyenda según el análisis, el orden refleja el orden de la pila

    if (option. find ( " ZBosonAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (Z,   " Z #rightarrow l ^ {+} l ^ {-} " , " f " );
leg-       > AddEntry (diboson, " Diboson " , " f " );
leg-       > AddEntry (ttbar, " t # bar {t} " , " f " );
leg-       > AddEntry (stop, " Single top " , " f " );
pierna-       > AddEntry (W,   " W + jets " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );

      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , Z: " << Z-> Integral () <<
              " , W: " << W-> Integral () <<
              " , diboson: " << diboson-> Integral () <<
              " , ttbar: " << ttbar -> Integral () <<
              " , detener: " << detener-> Integral () <<
              " , Total pred .: " << diboson-> Integral () + W-> Integral () + Z-> Integral () + ttbar -> Integral () + stop-> Integral () <<
              endl;
      }
    }

    // ------------------------------------------------ ------- //
    if (option. find ( " WBosonAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
pierna-       > AddEntry (W,   " W + jets " , " f " );
leg-       > AddEntry (Z,   " Z + jets " , " f " );
leg-       > AddEntry (diboson, " Diboson " , " f " );
leg-       > AddEntry (ttbar, " t # bar {t} " , " f " );
leg-       > AddEntry (stop, " Single top " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );
    
      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , W: " << W-> Integral () <<
              " , Z: " << Z-> Integral () <<
              " , diboson: " << diboson-> Integral () <<
		" , ttbar: " << ttbar -> Integral () <<
		" , detener: " << detener-> Integral () <<
		" , Total pred .: " << diboson-> Integral () + W-> Integral () + Z-> Integral () + ttbar -> Integral () + stop-> Integral () <<
		endl;
      }
    }

    // ------------------------------------------------ ------- //	
    if (option. find ( " SingleTopAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (stop_tq, " tq " , " f " );
leg-       > AddEntry (ttbar, " t # barra {t}, Wt, t # barra {b} " , " f " );
pierna-       > AddEntry (W,   " W + jets " , " f " );
leg-       > AddEntry (ZVV,   " Z, VV + jets " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );
      if (NORMSIG) leg-> AddEntry (stop_normsig, " tq_ {norm} " , " l " );

      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , detener (canal t): " << stop_tq-> Integral () <<
              " , ttbar y detener (Wt, tb): " << stop_tWtb-> Integral () <<
              " , W: " << W-> Integral () <<
              " , Z y diboson: " << ZVV-> Integral () <<
		" , Total pred .: " << W-> Integral () + ZVV-> Integral () + stop_tWtb-> Integral () + stop_tq-> Integral () <<
		endl;
      }
    }
    
    // ------------------------------------------------ ------- //
    if (option. find ( " ZZDiBosonAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (Z_Z, " ZZ " , " f " );
leg-       > AddEntry (WWZ, " WW, WZ " , " f " );
leg-       > AddEntry (topV,   " Otro " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );

      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , ZZ: " << Z_Z-> Integral () <<
              " , WW, WZ: " << WWZ-> Integral () <<
              " , top, top simple, chorros V +: " << topV-> Integral () <<
              " , Total pred .: " << WWZ-> Integral () + Z_Z-> Integral () + topV-> Integral () <<
                endl;
      }

    }

    // ------------------------------------------------ ------- //    
    if (option. find ( " WZDiBosonAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (W_Z, " WZ " , " f " );
leg-       > AddEntry (VV, " ZZ, WW " , " f " );
leg-       > AddEntry (V,   " V + jets " , " f " );
leg-       > AddEntry (arriba, " Otro " , " f " ); // ttbar + parte superior simple
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );

      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , WZ: " << W_Z-> Integral () <<
              " , ZZ, WW: " << VV-> Integral () <<
              " , V + chorros: " << V -> Integral () <<
              " , ttbar + stop: " << arriba-> Integral () <<
              " , Total pred .: " << W_Z-> Integral () + VV-> Integral () + V-> Integral () + arriba-> Integral () <<
              endl;
      }
      
    }

    // ------------------------------------------------ ------- //   
    if (option. find ( " TTbarAnalysis " )! = option. npos || option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (ttbar, " t # bar {t} " , " f " );
leg-       > AddEntry (V,   " V + jets " , " f " );
leg-       > AddEntry (stop, " Single top " , " f " );
leg-       > AddEntry (diboson, " Diboson " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );
      if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos && NORMSIG)
      {
	if ( después -> primero . buscar ( " LR " )! = opción. npos ) leg- > AddEntry (ZPrime_normsig, " m_ {Z '} = 1 TeV " , " l " );
      }

      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , parte superior simple: " << detener-> Integral () <<
              " , ttbar: " << ttbar-> Integral () <<
              " , V + chorros: " << V-> Integral () <<
              " , diboson: " << diboson-> Integral () <<
                " , Total pred .: " << diboson-> Integral () + V-> Integral () + ttbar-> Integral () + stop-> Integral () <<
                endl;
      }
    }

    // ------------------------------------------------ ------- //    
    if (option. find ( " HZZAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (Higgs, " Higgs " , " f " );
leg-       > AddEntry (Z_Z, " ZZ " , " f " );
leg-       > AddEntry (V,   " Otro " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );
      if (NORMSIG) leg-> AddEntry (Higgs_normsig, " Higgs_ {norma} " , " l " );
      
      if (RENDIMIENTOS) {
	cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
	  " , Higgs: " << Higgs-> Integral () <<
	  " , ZZ: " << Z_Z-> Integral () <<
	  " , Otro: " << V-> Integral () <<
	  " , Pred. Total: " << V-> Integral () + Z_Z-> Integral () <<
	  endl;
      }
    }
    
    // ------------------------------------------------ ------- //   
    if (option. find ( " HWWAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (Higgs, " Higgs " , " f " );
leg-       > AddEntry (diboson, " Diboson " , " f " );
leg-       > AddEntry (V,   " V + jets " , " f " );
leg-       > AddEntry (ttbar, " t # bar {t} " , " f " );
leg-       > AddEntry (stop, " Single top " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );
      if (NORMSIG) if ( fIter -> first . find ( " histI " )! = option. npos ) leg- > AddEntry (Higgs_normsig, " Higgs_ {norm} " , " l " );
      
      if (RENDIMIENTOS) {
	cout << " Número de eventos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
	  " , Higgs: " << Higgs-> Integral () <<
	  " , Diboson: " << diboson-> Integral () <<
	  " , V + chorros: " << V-> Integral () <<
	  " , ttbar: " << ttbar -> Integral () <<
	  " , detener: " << detener-> Integral () <<
	  " , Total pred .: " << diboson-> Integral () + V-> Integral () + ttbar -> Integral () + stop-> Integral () <<
	  endl;
      }
    }

    // ------------------------------------------------ ------- //    
    if (option. find ( " ZTauTauAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (Z_tautau,   " Z #rightarrow # tau # tau " , " f " );
leg-       > AddEntry (Z,   " Z #rightarrow ee, # mu # mu " , " f " );
pierna-       > AddEntry (W,   " W + jets " , " f " );
leg-       > AddEntry (topV, " Otro " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );
      
      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , Z-> tautau: " << Z_tautau-> Integral () <<             
              " , Z-> ee, mumu: " << Z-> Integral () <<
              " , W + chorros: " << W-> Integral () <<
              " , ttbar, single top, diboson: " << topV-> Integral () <<
              " , Total pred .: " << Z-> Integral () + Z_tautau-> Integral () + W-> Integral () + topV-> Integral () <<
                endl;
      }
    }

    // ------------------------------------------------ ------- //    
    if (option. find ( " SUSYAnalysis " )! = option. npos ) {
leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (Z,   " Z + jets " , " f " );
leg-       > AddEntry (diboson, " Diboson " , " f " );
leg-       > AddEntry (ttbar, " t # bar {t} " , " f " );
leg-       > AddEntry (stop, " Single top " , " f " );
pierna-       > AddEntry (W,   " W + jets " , " f " );
leg-       > AddEntry (histstack, " Stat. unc. " , " f " );

      if (RENDIMIENTOS) {
              cout << " Rendimientos: " << " Datos: " << datos [ después -> primero ] -> Integral () <<
              " , diboson: " << diboson-> Integral () <<
              " , Z + chorros: " << Z-> Integral () <<
              " , W + chorros: " << W-> Integral () <<
              " , parte superior simple: " << detener-> Integral () <<
              " , ttbar: " << ttbar-> Integral () <<
              " , Total pred .: " << diboson-> Integral () + Z-> Integral () + W-> Integral () + ttbar-> Integral () + stop-> Integral () <<
                endl;
      }
    }

    // ////////////////////////////////////////////////// ////////////
        
    // solo para SUSY
    TLegend * leg2; leg2 = nueva  TLegend (); leg2 = nueva  TLegend ( 0.45 , 0.45 , 0.93 , 0.50 );
    leg2-> SetFillStyle ( 0 ); leg2-> SetBorderSize ( 0 ); leg2-> SetTextAlign ( 32 );
    leg2-> SetTextFont ( 42 ); leg2-> SetTextSize ( 0.05 ); leg2-> SetMargin ( 0.22 ); leg2-> SetTextAlign ( 32 );
    if (option. find ( " SUSYAnalysis " )! = option. npos ) if (NORMSIG) leg2-> AddEntry (slep600DM300_normsig, " m (#tilde {l}, # chi ^ {0} _ {1}) = (600,300 ) GeV " , " l " );

    // dibujar todo
    pila-> Dibujar ( " HISTsame " );
    histstack-> Draw ( " e2same " );
    fIter -> segundo -> Draw ( " sameE1 " );
    
    // dibuja la señal normalizada en los gráficos
    si (NORMSIG) {
      if (option. find ( " HZZAnalysis " )! = option. npos ) {Higgs_normsig-> Draw ( " HISTsame " );}
      if (option. find ( " HWWAnalysis " )! = option. npos ) { if ( fIter -> first . find ( " histI " )! = option. npos ) Higgs_normsig-> Draw ( " HISTsame " );}
      if (option. find ( " SingleTopAnalysis " )! = option. npos ) {stop_normsig-> Draw ( " HISTsame " );}
      if (opción. encontrar ( " SUSYAnalysis " )! = opción. npos ) {slep600DM300_normsig-> Draw ( " HISTsame " ); leg2-> Draw ( " igual " );}
      if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) { if ( fIter -> first . find ( " LR " )! = option. npos ) ZPrime_normsig-> Draw ( " HISTsame " ); }
    }
    

    // ------------------------------------------------ ------- //
    // para el caso Hyy, solo tenemos datos y Higgs MC
    if (option. find ( " HyyAnalysis " )! = option. npos ) {

      // imprimir rendimientos esperados
      if (RENDIMIENTOS) {  
      cout << " Eventos de señal esperados (ggH): " << ggH125_gamgam [ fIter -> first ] -> Integral () << endl;
      cout << " Eventos de señales esperados (VBF): " << VBFH125_gamgam [ fIter -> first ] -> Integral () << endl;
      cout << " Eventos de señal esperados (WH): " << WH125_gamgam [ fIter -> first ] -> Integral () << endl;
      cout << " Eventos de señal esperados (ZH): " << ZH125_gamgam [ fIter -> first ] -> Integral () << endl;
      cout << " Eventos de señal esperados (ttH): " << ttH125_gamgam [ fIter -> first ] -> Integral () << endl;
      cout << " Eventos de señales esperados (todos): " << Higgs-> Integral () << endl;
      }

 
      // La distribución de la señal se modela empíricamente como un solo gaussiano en la ventana de masa 120 - 130 GeV
      // En caso de que desee ejecutar este ajuste, haga:
      // Higgs-> Fit ("gaus", "", "", 120., 130.);

      // La función de ajuste total es entonces la suma de la señal de Higgs (Gauss) y el fondo (polinomio)
      cout << " === Ajustar un polinomio de tercer orden + Gaussiano a datos == " << endl;
      ajuste = nuevo  TF1 ( " ajuste " , " ([0] + [1] * x + [2] * x ^ 2 + [3] * x ^ 3) + [4] * exp (-0,5 * ((x- [5]) / [6]) ^ 2) " , 105 , 160 );

      // Establecemos los valores de los parámetros ajustados a partir del ajuste gaussiano
ajustar-       > FixParameter ( 5 , 125.0 ); // siempre fijado a 125 GeV

      if ( después -> primero . encontrar ( " mYY_bin1 " )! = opción. npos ) {
ajustar-         > FixParameter ( 4 , 119.1 ); // este valor se obtuvo del ajuste gaussiano
ajustar-         > FixParameter ( 6 , 2.38 );  // este valor se obtuvo del ajuste gaussiano
      }
      if ( después -> primero . find ( " mYY_cat_bin1 " )! = option. npos ) {
ajustar-         > FixParameter ( 4 , 23.2 ); // este valor se obtuvo del ajuste gaussiano
ajustar-         > FixParameter ( 6 , 1.83 );  // este valor se obtuvo del ajuste gaussiano
      }

      // aquí estamos finalmente encajando
      datos [ fIter -> primero ] -> Ajustar ( " ajustar " , " " , " igual: e " , 105. , 160. );
      TF1 * fitresult = data [ fIter -> first ] -> GetFunction ( " fit " );
      cout << " Chi2 / NDF: " << fitresult-> GetChisquare () / fitresult-> GetNDF () << endl;
      cout << " ================================ " << endl;

      // La forma funcional para modelar la distribución de fondo se elige como un polinomio de tercer orden restringido a 105 <m (yy) <160 GeV
      bgd = nuevo  TF1 ( " bgd " , " ([0] + [1] * x + [2] * x ^ 2 + [3] * x ^ 3) " , 105 , 160 );
      // lo construimos usando los parámetros del ajuste anterior
      bgd-> SetParameter ( 0 , ajuste-> GetParameter ( 0 ));
      bgd-> SetParameter ( 1 , fit- > GetParameter ( 1 ));
      bgd-> SetParameter ( 2 , fit- > GetParameter ( 2 ));
      bgd-> SetParameter ( 3 , ajuste-> GetParameter ( 3 ));

      // establecer el estilo de los gráficos
      bgd-> SetLineColor ( 4 );
      bgd-> SetLineStyle ( 2 );
      bgd-> SetLineWidth ( 2 );
      bgd-> Dibujar ( " igual " );
 
ajustar-       > SetLineColor ( 2 );
ajustar-       > SetLineStyle ( 1 );
ajustar-       > SetLineWidth ( 2 );
      ajustar-> Dibujar ( " igual: e " );

leg-       > AddEntry (data [ fIter -> first ], " Data " , " lep " );
leg-       > AddEntry (bgd,    " Fondo " , " l " );
leg-       > AddEntry (ajuste,    " Señal + bkg " , " l " );
leg-       > AddEntry (Higgs, " Señal " , " l " );

    }


    pierna-> Dibujar ( " igual " );

    ATLASLabel ( 0,18 , 0,87 );
    

    // ////////////////////////////////////////////////// ////////////////////////////////
    // el pad inferior contiene la relación de datos a MC
    // para Hyy, contiene el resto de datos y se ajusta
    pad1-> cd ();
    pad1-> GetFrame () -> SetY1 ( 2 );
    pad1-> Dibujar ();

    // crea la gráfica de razón  
    TH1F * h_ratio = (TH1F *) datos [ fIter -> first ] -> Clone ( " h_ratio " );

    if (! (option. find ( " HyyAnalysis " )! = option. npos )) {
      h_ratio-> Divide ((TH1F *) histstack-> Clone ());
      h_ratio-> GetYaxis () -> SetTitle ( " Datos / Pred    " );
//       h_ratio-> GetYaxis () -> SetTitle ("Datos / Pred");
    }
   
    if (option. find ( " HyyAnalysis " )! = option. npos ) {
      // crea la trama de descanso
      h_ratio-> Agregar (bgd, - 1 );
      h_ratio-> GetYaxis () -> SetTitle ( " Datos - bkg       " );
   
      flotar errore;
      int nbine = data [ fIter -> first ] -> GetNbinsX ();
      para ( int i_bin = 0 ; i_bin <= nbine; i_bin ++) {
        errore = data [ fIter -> first ] -> GetBinError (i_bin);
        h_ratio-> SetBinError (i_bin, errore);
      } 

      TH1F * copy_fit = nuevo  TH1F ( " copy_fit " , " copy_fit " , 5500 , 105 , 160 ); //   suave
      copy_fit-> Eval (ajuste);
      copy_fit-> SetLineColor ( 2 );
      copy_fit-> SetLineStyle ( 1 );
      copy_fit-> SetLineWidth ( 2 );

      h_ratio2 = (TH1F *) copy_fit-> Clon ( " h_ratio2 " );
      h_ratio2-> Agregar (bgd, - 1 );
      eliminar copy_fit;
    }

    // agrega una línea en 1
    TLine * hline;
    hline = new  TLine (h_ratio-> GetXaxis () -> GetXmin (), 1 , h_ratio-> GetXaxis () -> GetXmax (), 1 );
    hline-> SetLineColor ( kGray + 2 );
    hline-> SetLineWidth ( 2 );
    hline-> SetLineStyle ( 1 );

    if (option. find ( " HyyAnalysis " )! = option. npos ) {
      hline = new  TLine (h_ratio-> GetXaxis () -> GetXmin (), 0 , h_ratio-> GetXaxis () -> GetXmax (), 0 );
      hline-> SetLineColor ( 4 );
      hline-> SetLineWidth ( 2 );
      hline-> SetLineStyle ( 2 );
    }

    gStyle -> SetEndErrorSize ( 1. );
    h_ratio-> GetYaxis () -> CenterTitle ();
    h_ratio-> GetYaxis () -> SetNdivisions ( 504 , falso );
    if (opción. encontrar ( " HyyAnalysis " )! = opción. npos ) h_ratio-> GetYaxis () -> SetNdivisions ( 503 , false );

    h_ratio-> Dibujar ( " 0E1 " );
    hline-> Dibujar ();

    // cosméticos
    h_ratio-> SetMinimum ( 0 );
    h_ratio-> SetMaximum ( 2 );
    if (option. find ( " HyyAnalysis " )! = option. npos ) {
        if ( después -> primero . buscar ( " _cat_ " )! = opción. npos ) {h_ratio-> SetMinimum (- 30 ); h_ratio-> SetMaximum ( 60 ); }
	else {h_ratio-> SetMinimum (- 125 ); h_ratio-> SetMaximum ( 250 ); }
    }

    h_ratio-> GetXaxis () -> SetTitle (   después -> segundo -> GetXaxis () -> GetTitle ());
    h_ratio-> GetXaxis () -> SetTitleSize ( 0.15 );
    h_ratio-> GetXaxis () -> SetLabelSize ( 0.13 );
    h_ratio-> GetXaxis () -> SetTitleOffset ( 1.2 );
    h_ratio-> GetYaxis () -> SetTitleSize ( 0.12 );
    h_ratio-> GetYaxis () -> SetTitleOffset ( 0.45 );
    h_ratio-> GetYaxis () -> SetLabelSize ( 0.10 );
    h_ratio-> GetYaxis () -> SetLabelOffset ( 0.01 );
    h_ratio-> GetXaxis () -> SetLabelOffset ( 0.035 );


    datos [ fIter -> primero ] -> GetXaxis () -> SetLabelSize ( 0 );
    gPad -> RedrawAxis ();
    pad1-> cd ();
    if (! (option. find ( " HyyAnalysis " )! = option. npos )) pad1-> cd () -> SetGridy ();
    if (option. find ( " HyyAnalysis " )! = option. npos ) h_ratio2-> Draw ( " MISMO " );

    h_ratio-> Dibujar ( " SAME0E1 " );
    h_ratio-> Dibujar ( " SAMEAXIS " );
    h_ratio-> GetYaxis () -> Dibujar ();
    h_ratio-> Dibujar ( " SAME0E1 " );

    pad0-> cd ();
    TAxis * Ay1 = NULL ;
    Ay1 = fIter -> segundo -> GetXaxis ();
    Ay1-> SetLabelSize ( 0 );
    Ay1-> SetTitleSize ( 0 );


    // ////////////////////////////////////////////////// /////////////
    // Opciones de dibujo

    if (option. find ( " WBosonAnalysis " )! = option. npos ) {
      pad0-> SetLogy ( 1 );
      fIter -> segundo -> SetMinimum ( 100 );
      fIter -> segundo -> SetMaximum ( 1e12 );
      if ( fIter -> first . find ( " leptch " )! = option. npos )       fIter -> second -> SetMaximum ( 1e14 );
    }

    if (option. find ( " ZBosonAnalysis " )! = option. npos ) {
     pad0-> SetLogy ( 1 );
     fIter -> segundo -> SetMinimum ( 30 );
     fIter -> segundo -> SetMaximum ( 1e10 );
     if ( fIter -> first . find ( " leptch " )! = option. npos )       fIter -> second -> SetMaximum ( 1e12 );
    }
    
    if (option. find ( " TTbarAnalysis " )! = option. npos ) {
      pad0-> SetLogy ( 1 );
      fIter -> segundo -> SetMinimum ( 10 );
      fIter -> segundo -> SetMaximum ( 1e8 );
      if ( después -> primero . find ( " Topmass " )! = option. npos ) {
	pad0-> SetLogy ( 0 );
	fIter -> segundo -> SetMinimum ( 1 );
	fIter -> segundo -> SetMaximum ( 1e4 );
      }
      if ( después -> primero . find ( " Wmass " )! = option. npos ) {
	pad0-> SetLogy ( 0 );
	fIter -> segundo -> SetMinimum ( 1 );
	Fiter -> segundos -> setMaximum ( 5E3 );
      }
      if ( después -> primero . encontrar ( " leptch " )! = opción. npos ) {
	pad0-> SetLogy ( 1 );
	fIter -> segundo -> SetMinimum ( 10 );
	fIter -> segundo -> SetMaximum ( 1e9 );
      }
    }
    
    if (option. find ( " SUSYAnalysis " )! = option. npos ) {
      if ( después -> primero . buscar ( " SFOS " )! = opción. npos ) {
        pad0-> SetLogy ( 1 );
        fIter -> segundo -> SetMinimum ( 10 );
        fIter -> segundo -> SetMaximum ( 1e11 );
      }
      if ( después -> primero . buscar ( " SR " )! = opción. npos ) {
        pad0-> SetLogy ( 1 );
        fIter -> segundo -> SetMinimum ( 0.02 );
        fIter -> segundo -> SetMaximum ( 1e5 );
      }
    }

    if (option. find ( " HZZAnalysis " )! = option. npos )
    {
     if ( fIter -> first . find ( " mLL1 " )! = option. npos ) fIter -> second -> SetMaximum ( 150 );
     if ( fIter -> first . find ( " mLL2 " )! = option. npos ) fIter -> second -> SetMaximum ( 100 );
     if ( fIter -> first . find ( " mass_four " )! = option. npos ) fIter -> second -> SetMaximum ( 35 );
     if ( fIter -> first . find ( " mass_ext " )! = option. npos ) fIter -> second -> SetMaximum ( 40 );
    }

    if (option. find ( " HyyAnalysis " )! = option. npos ) {
      if ( después -> primero . buscar ( " bin1 " )! = opción. npos ) {
        if ( fIter -> first . find ( " _cat_ " )! = option. npos ) { fIter -> second -> SetMaximum ( 1000 );}
	si no  después -> segundo -> SetMaximum ( 8e3 );
      }
      if ( después -> primero . buscar ( " bin2 " )! = opción. npos ) {
	     if ( después -> primero . buscar ( " _cat_ " )! = opción. npos ) { después -> segundo -> SetMaximum ( 500 );}
	     si no  	      después -> segundo -> SetMaximum ( 4500 );
      }
    }


    // ////////////////////////////////////////////////// //////
    gPad -> RedrawAxis ();
 
    // imprimir el lienzo en un archivo png (pdf ...)    
    PrintCanvas (c, fIter -> first );
    
  }
  
  volver ;
}

// /
void  Trazado :: PrintCanvas (TCanvas * c1, String title) {
  
  string outFolder = " histogramas " ;
  std :: string tpng = outFolder + " / " + título + " .png " ;
  c1-> Guardar como (tpng. c_str ());
 
  si (SAVEPDF)
   { 
     std :: string tpdf = outFolder + " / " + título + " .pdf " ;
     c1-> Guardar como (tpdf. c_str ());
   }

  si (SAVEROOT)
   { 
     std :: string troot = outFolder + " / " + title + " .root " ;
     c1-> Guardar como (troot. c_str ());
   }

  volver ;
}

// /
vacío  trazado :: getHistoSettings () {

  // comprobamos el nombre de los 12 análisis
  if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos || option. find ( " SingleTopAnalysis " )! = option. npos || option. find ( " ZTauTauAnalysis " )! = option. npos || option. find ( " WBosonAnalysis " )! = opción. npos opción ||. encontrar ( " ZBosonAnalysis " )! = opción. npos opción ||. encontrar ( "TTbarAnalysis " )! = Opción. Npos opción ||. Encontrar ( " HyyAnalysis " )! = Opción. Npos opción ||. Encontrar ( " WZDiBosonAnalysis " )! = Opción. Npos opción ||. Encontrar ( " ZZDiBosonAnalysis " )! = opción. npos || opción. find ( " HWWAnalysis " )! = opción. npos || opción. find ( " HZZAnalysis " )! = opción. npos|| opción. find ( " SUSYAnalysis " )! = opción. npos ) cout << " Opción de análisis encontrada, procediendo ... " << endl;
  otra cosa {cout << " opción Análisis de no encontrado! \ n uso: ./plot [WBosonAnalysis, ZBosonAnalysis, TTbarAnalysis, SingleTopAnalysis, WZDiBosonAnalysis, ZZDiBosonAnalysis, HWWAnalysis, HZZAnalysis, ZTauTauAnalysis, HyyAnalysis, SUSYAnalysis, ZPrimeBoostedAnalysis] [ubicación de OutputDir_AnalysisName] \ n  " << endl; salir ( 1 );}

 
  // guarda los nombres de los histogramas para más tarde  
  hset. claro ();
  
  // leer en el archivo de configuración
  std :: string ifile;

  if (option. find ( " WBosonAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_WBosonAnalysis.txt " ;}
  if (option. find ( " TTbarAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_TTbarAnalysis.txt " ;}
  if (option. find ( " SingleTopAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_SingleTopAnalysis.txt " ;}
  if (option. find ( " ZPrimeBoostedAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_ZPrimeBoostedAnalysis.txt " ;}
  if (option. find ( " ZBosonAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_ZBosonAnalysis.txt " ;}
  if (option. find ( " HWWAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_HWWAnalysis.txt " ;}
  if (option. find ( " SUSYAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_SUSYAnalysis.txt " ;}
  if (option. find ( " WZDiBosonAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_WZDiBosonAnalysis.txt " ;}
  if (option. find ( " ZZDiBosonAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_ZZDiBosonAnalysis.txt " ;}
  if (option. find ( " HZZAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_HZZAnalysis.txt " ;}
  if (option. find ( " ZTauTauAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_ZTauTauAnalysis.txt " ;}
  if (option. find ( " HyyAnalysis " )! = option. npos ) {ifile = " list_histos / HistoList_HyyAnalysis.txt " ;}

  std :: cout << " Lista de lectura de histogramas de: " << ifile. c_str () << "  \ n  " << std :: endl;

  ifstream input (ifile. c_str ());
  std :: línea de cadena;
  while ( getline (entrada, línea)) {
    if (línea. buscar ( " # " )! = línea. npos ) continuar ; // un # es un comentario y no se lee
    std :: cadena n;
    istringstream linestream (línea);
    getline (linestream, n, ' \ n ' );
    HistoHandler * h = nuevo  HistoHandler (n);
    hset. retroceso (h);
  }
  volver ;
}

// /
HistoHandler :: HistoHandler () {
}

// /
HistoHandler :: HistoHandler (std :: nombre de cadena) {
  _name = nombre;
}

// /
HistoHandler :: ~ HistoHandler () {
}

// /
std :: string HistoHandler :: GetName () {
  return _name;
}
// ////////////////////////////////////////////////// /////
